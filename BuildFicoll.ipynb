# %% [markdown]
# # Building Ficoll Polymers

# %% [markdown]
# This notebook assembles Ficoll polymers of arbitrary size based on given input parameters

# %% [markdown]
# We begin by loading modules.

# %%
import os
import sys
import numpy as np
import mdtraj as md
import math
import copy
import random

# %% [markdown]
# Let's read glycerol and sucrose molecules

# %%
class Molecule:
    def __init__(m,fname):
        m.xyz={}
        m.pdb=md.load_pdb(fname)
        m.mapatom={}
        for n in m.pdb.topology.atoms:
            m.mapatom[f'{n.residue.name}:{n.name}']=n.index
            
    def center(m):
        return md.compute_center_of_mass(m.pdb)[0]
        
    def getatom(m,key):
        return np.array(m.pdb.xyz[0][m.mapatom[key]])
        
gmol=[]
gmol+=[Molecule('glycerol1.pdb')]
gmol+=[Molecule('glycerol2.pdb')]
gmol+=[Molecule('glycerol3.pdb')]

smol=[]
smol+=[Molecule('sucrose1.pdb')]
smol+=[Molecule('sucrose2.pdb')]
smol+=[Molecule('sucrose3.pdb')]
smol+=[Molecule('sucrose4.pdb')]

# %%
def bond(mol,res,a1,a2):
    inx1=mol.pdb.topology.select(f"resname {res} and name {a1}")
    inx2=mol.pdb.topology.select(f"resname {res} and name {a2}")
    
    b=mol.pdb.xyz[0][inx1]-mol.pdb.xyz[0][inx2]

    return np.linalg.norm(b)

def angle(mol,res,a1,a2,a3):
    inx1=mol.pdb.topology.select(f"resname {res} and name {a1}")
    inx2=mol.pdb.topology.select(f"resname {res} and name {a2}")
    inx3=mol.pdb.topology.select(f"resname {res} and name {a3}")

    b1=mol.pdb.xyz[0][inx1]-mol.pdb.xyz[0][inx2]
    b2=mol.pdb.xyz[0][inx3]-mol.pdb.xyz[0][inx2]

    return math.acos(np.dot(b1[0],b2[0])/(np.linalg.norm(b1)*np.linalg.norm(b2)))*180.0/math.pi

def dihedral(mol,res,a1,a2,a3,a4):
    inx1=mol.pdb.topology.select(f"resname {res} and name {a1}")
    inx2=mol.pdb.topology.select(f"resname {res} and name {a2}")
    inx3=mol.pdb.topology.select(f"resname {res} and name {a3}")
    inx4=mol.pdb.topology.select(f"resname {res} and name {a4}")

    b1=mol.pdb.xyz[0][inx1]-mol.pdb.xyz[0][inx2]
    b2=mol.pdb.xyz[0][inx3]-mol.pdb.xyz[0][inx2]
    b3=mol.pdb.xyz[0][inx4]-mol.pdb.xyz[0][inx3]

    b0xb1 = np.cross(b1[0], b2[0])
    b1xb2 = np.cross(b3[0], b2[0])
    b0xb1_x_b1xb2 = np.cross(b0xb1, b1xb2)

    y = np.dot(b0xb1_x_b1xb2, b2[0])*(1.0/np.linalg.norm(b2))
    x = np.dot(b0xb1, b1xb2)

    return np.degrees(np.arctan2(y, x))

# %%
class GlycerolTopology:
    def __init__(g,mol):
        g.hlist=mol.pdb.topology.select("not type H")
        g.o1inx=mol.pdb.topology.select("name O1")
        g.c1inx=mol.pdb.topology.select("name C1")
        g.c2inx=mol.pdb.topology.select("name C2")
        g.c3inx=mol.pdb.topology.select("name C3")
        g.o3inx=mol.pdb.topology.select("name O3")
        g.o2inx=mol.pdb.topology.select("name O2")
        g.excllist=mol.pdb.topology.select("not name O1 and not name C1 and not type H")
        g.calcIC(mol)

    def calcIC(g,mol):
        g.bond={}
        g.bond['O1-C1']=bond(mol,"MGL","O1","C1")
        g.bond['C1-C2']=bond(mol,"MGL","C1","C2")
        g.bond['C2-C3']=bond(mol,"MGL","C2","C3")
        g.bond['C3-O3']=bond(mol,"MGL","C3","O3")
        g.bond['C2-O2']=bond(mol,"MGL","C2","O2")
        
        g.angle={}
        g.angle['O1-C1-C2']=angle(mol,"MGL","O1","C1","C2")
        g.angle['C1-C2-C3']=angle(mol,"MGL","C1","C2","C3")
        g.angle['C2-C3-O3']=angle(mol,"MGL","C2","C3","O3")
        g.angle['C1-C2-O2']=angle(mol,"MGL","C1","C2","O2") 
        
        g.dihedral={}
        g.dihedral['O1-C1-C2-C3']=dihedral(mol,"MGL","O1","C1","C2","C3")
        g.dihedral['C1-C2-C3-O3']=dihedral(mol,"MGL","C1","C2","C3","O3")
        g.dihedral['O1-C1-C2-O2']=dihedral(mol,"MGL","O1","C1","C2","O2")

# %%
class SucroseTopology:
    def __init__(s,mol):
        s.calcIC(mol)
        
        s.hlist=mol.pdb.topology.select("not type H")
        
        s.o1inx={}
        s.c1inx={}
        s.c2inx={}
        s.c3inx={}
        s.c4inx={}
        
        s.excllist={}
        
        s.o1inx['f1']=mol.pdb.topology.select("resname BFRU and name O1")
        s.c1inx['f1']=mol.pdb.topology.select("resname BFRU and name C1")
        s.c2inx['f1']=mol.pdb.topology.select("resname BFRU and name C2")
        s.c3inx['f1']=mol.pdb.topology.select("resname BFRU and name C3")
        s.c4inx['f1']=mol.pdb.topology.select("resname BFRU and name C4")

        s.excllist['f1']=mol.pdb.topology.select(\
                f"not index {s.o1inx['f1'][0]} and not index {s.c1inx['f1'][0]} and \
                  not index {s.c2inx['f1'][0]} and not type H")
        
        s.o1inx['f6']=mol.pdb.topology.select("resname BFRU and name O6")
        s.c1inx['f6']=mol.pdb.topology.select("resname BFRU and name C6")
        s.c2inx['f6']=mol.pdb.topology.select("resname BFRU and name C5")
        s.c3inx['f6']=mol.pdb.topology.select("resname BFRU and name C4")
        s.c4inx['f6']=mol.pdb.topology.select("resname BFRU and name C3")

        s.excllist['f6']=mol.pdb.topology.select(\
                f"not index {s.o1inx['f6'][0]} and not index {s.c1inx['f6'][0]} and \
                  not index {s.c2inx['f6'][0]} and not type H")
        
        s.o1inx['g2']=mol.pdb.topology.select("resname AGLC and name O2")
        s.c1inx['g2']=mol.pdb.topology.select("resname AGLC and name C2")
        s.c2inx['g2']=mol.pdb.topology.select("resname AGLC and name C3")
        s.c3inx['g2']=mol.pdb.topology.select("resname AGLC and name C4")
        s.c4inx['g2']=mol.pdb.topology.select("resname AGLC and name C5")
        
        s.excllist['g2']=mol.pdb.topology.select(\
                f"not index {s.o1inx['g2'][0]} and not index {s.c1inx['g2'][0]} and \
                  not index {s.c2inx['g2'][0]} and not type H")

        s.o1inx['g6']=mol.pdb.topology.select("resname AGLC and name O6")
        s.c1inx['g6']=mol.pdb.topology.select("resname AGLC and name C6")
        s.c2inx['g6']=mol.pdb.topology.select("resname AGLC and name C5")
        s.c3inx['g6']=mol.pdb.topology.select("resname AGLC and name C4")
        s.c4inx['g6']=mol.pdb.topology.select("resname AGLC and name C3")
        
        s.excllist['g6']=mol.pdb.topology.select(\
                f"not index {s.o1inx['g6'][0]} and not index {s.c1inx['g6'][0]} and \
                  not index {s.c2inx['g6'][0]} and not type H")

        s.o1inx['g3']=mol.pdb.topology.select("resname AGLC and name O3")
        s.c1inx['g3']=mol.pdb.topology.select("resname AGLC and name C3")
        s.c2inx['g3']=mol.pdb.topology.select("resname AGLC and name C4")
        s.c3inx['g3']=mol.pdb.topology.select("resname AGLC and name C5")
        s.c4inx['g3']=mol.pdb.topology.select("resname AGLC and name C6")

        s.excllist['g3']=mol.pdb.topology.select(\
                f"not index {s.o1inx['g3'][0]} and not index {s.c1inx['g3'][0]} and \
                  not index {s.c2inx['g3'][0]} and not type H")
        
    def calcIC(s,mol):
        s.bond={}
        s.bond['f1']={}
        s.bond['f1']['O1-C1']=bond(mol,"BFRU","O1","C1")
        s.bond['f1']['C1-C2']=bond(mol,"BFRU","C1","C2")
        s.bond['f1']['C2-C3']=bond(mol,"BFRU","C2","C3")
        s.bond['f1']['C3-C4']=bond(mol,"BFRU","C3","C4")

        s.bond['f6']={}
        s.bond['f6']['O1-C1']=bond(mol,"BFRU","O6","C6")
        s.bond['f6']['C1-C2']=bond(mol,"BFRU","C6","C5")
        s.bond['f6']['C2-C3']=bond(mol,"BFRU","C5","C4")
        s.bond['f6']['C3-C4']=bond(mol,"BFRU","C4","C3")

        s.bond['g2']={}
        s.bond['g2']['O1-C1']=bond(mol,"AGLC","O2","C2")
        s.bond['g2']['C1-C2']=bond(mol,"AGLC","C2","C3")
        s.bond['g2']['C2-C3']=bond(mol,"AGLC","C3","C4")
        s.bond['g2']['C3-C4']=bond(mol,"AGLC","C4","C5")

        s.bond['g6']={}
        s.bond['g6']['O1-C1']=bond(mol,"AGLC","O6","C6")
        s.bond['g6']['C1-C2']=bond(mol,"AGLC","C6","C5")
        s.bond['g6']['C2-C3']=bond(mol,"AGLC","C5","C4")
        s.bond['g6']['C3-C4']=bond(mol,"AGLC","C4","C3")

        s.bond['g3']={}
        s.bond['g3']['O1-C1']=bond(mol,"AGLC","O3","C3")
        s.bond['g3']['C1-C2']=bond(mol,"AGLC","C3","C4")
        s.bond['g3']['C2-C3']=bond(mol,"AGLC","C4","C5")
        s.bond['g3']['C3-C4']=bond(mol,"AGLC","C5","C6")

        s.angle={}
        s.angle['f1']={}
        s.angle['f1']['O1-C1-C2']=angle(mol,"BFRU","O1","C1","C2")
        s.angle['f1']['C1-C2-C3']=angle(mol,"BFRU","C1","C2","C3")
        s.angle['f1']['C2-C3-C4']=angle(mol,"BFRU","C2","C3","C4")

        s.angle['f6']={}
        s.angle['f6']['O1-C1-C2']=angle(mol,"BFRU","O6","C6","C5")
        s.angle['f6']['C1-C2-C3']=angle(mol,"BFRU","C6","C5","C4")
        s.angle['f6']['C2-C3-C4']=angle(mol,"BFRU","C5","C4","C3")
    
        s.angle['g2']={}
        s.angle['g2']['O1-C1-C2']=angle(mol,"AGLC","O2","C2","C3")
        s.angle['g2']['C1-C2-C3']=angle(mol,"AGLC","C2","C3","C4")
        s.angle['g2']['C2-C3-C4']=angle(mol,"AGLC","C3","C4","C5")

        s.angle['g6']={}
        s.angle['g6']['O1-C1-C2']=angle(mol,"AGLC","O6","C6","C5")
        s.angle['g6']['C1-C2-C3']=angle(mol,"AGLC","C6","C5","C4")
        s.angle['g6']['C2-C3-C4']=angle(mol,"AGLC","C5","C4","C3")

        s.angle['g3']={}
        s.angle['g3']['O1-C1-C2']=angle(mol,"AGLC","O3","C3","C4")
        s.angle['g3']['C1-C2-C3']=angle(mol,"AGLC","C3","C4","C5")
        s.angle['g3']['C2-C3-C4']=angle(mol,"AGLC","C4","C5","C6")
                
        s.dihedral={}
        s.dihedral['f1']={}
        s.dihedral['f1']['O1-C1-C2-C3']=dihedral(mol,"BFRU","O1","C1","C2","C3")
        s.dihedral['f1']['C1-C2-C3-C4']=dihedral(mol,"BFRU","C1","C2","C3","C4")

        s.dihedral['f6']={}
        s.dihedral['f6']['O1-C1-C2-C3']=dihedral(mol,"BFRU","O6","C6","C5","C4")
        s.dihedral['f6']['C1-C2-C3-C4']=dihedral(mol,"BFRU","C6","C5","C4","C3")

        s.dihedral['g2']={}
        s.dihedral['g2']['O1-C1-C2-C3']=dihedral(mol,"AGLC","O2","C2","C3","C4")
        s.dihedral['g2']['C1-C2-C3-C4']=dihedral(mol,"AGLC","C2","C3","C4","C5")

        s.dihedral['g6']={}
        s.dihedral['g6']['O1-C1-C2-C3']=dihedral(mol,"AGLC","O6","C6","C5","C4")
        s.dihedral['g6']['C1-C2-C3-C4']=dihedral(mol,"AGLC","C6","C5","C4","C3")

        s.dihedral['g3']={}
        s.dihedral['g3']['O1-C1-C2-C3']=dihedral(mol,"AGLC","O3","C3","C4","C5")
        s.dihedral['g3']['C1-C2-C3-C4']=dihedral(mol,"AGLC","C3","C4","C5","C6")

# %%
gtop=[]
for i in range(len(gmol)):
    gtop+=[GlycerolTopology(gmol[i])]

stop=[]
for i in range(len(smol)):
    stop+=[SucroseTopology(smol[i])]

# %%
class GlycerolUnit:
    def __init__(g,inx,mol,top):
        g.index=inx
        g.resid=inx
        g.mol=copy.deepcopy(mol)
        g.top=top
        g.mapsite={'C1':'MGL:C1', 'O1':'MGL:O1', 'C3':'MGL:C3', 'O3':'MGL:O3'}
        g.connect={}
        g.connectsite={}

    def connectTo(g,site,sucrose,ssite):
        g.connect[site]=sucrose
        g.connectsite[site]=ssite
        
    def nconnect(g):
        return(len(g.connect.values()))
    
    def getatom(g,site,atom):
        return g.mol.getatom(g.mapsite[f'{atom}{site}'])

# %%
class SucroseUnit:
    def __init__(s,inx,mol,top):
        s.index=inx
        s.resid=inx
        s.mol=copy.deepcopy(mol)
        s.mapsite={'Cf1':'BFRU:C1', 'Of1':'BFRU:O1',\
                   'Cf6':'BFRU:C6', 'Of6':'BFRU:O6',\
                   'Cg2':'AGLC:C2', 'Og2':'AGLC:O2',\
                   'Cg6':'AGLC:C6', 'Og6':'AGLC:O6',\
                   'Cg3':'AGLC:C3', 'Og3':'AGLC:O3'}
        
        s.connect={}
        s.connectsite={}
        s.top=top
    
    def connectTo(s,site,glycerol,gsite):
        s.connect[site]=glycerol
        s.connectsite[site]=gsite
        
    def nconnect(s):
        return(len(s.connect.values()))
    
    def nlink(s):
        n=0
        for g in s.connect.values():
            if g.nconnect()>1: n+=1
        return n
    
    def nlone(s):
        return s.nconnect()-s.nlink()

    def getatom(s,site,atom):
        return s.mol.getatom(s.mapsite[f'{atom}{site}'])

# %%
class Ficoll:
    mw={}
    mw['sucrose'] = 342.301
    mw['glycerol'] = 92.0952
    mw['linkdel'] = (15.9994+1.008+1.008)
    
    seg='PROF'
    
    def __init__(f):
        f.sucrose=[]
        f.glycerol=[]
    
    def closest(f,m,list):        
        mind=999999.0
        
        for s in f.sucrose:
            d=minDist(s,m,s.top.hlist,list)
            if (d<mind):
                mind=d
        for g in f.glycerol:
            d=minDist(g,m,g.top.hlist,list)
            if (d<mind):
                mind=d
        return mind
    
    def alignSucroseToGlycerol(f,suc,ssite,igly,gsite):
        cg=f.glycerol[igly].getatom(gsite,'C')
        og=f.glycerol[igly].getatom(gsite,'O')
        
        
        spdb=suc.mol.pdb
        tpdb=copy.deepcopy(spdb)
        
        os=og
        tpdb.xyz[0][suc.top.o1inx[ssite]]=[os]      
        
        cs=buildFromIC(f.glycerol[igly].mol.center(),cg,os,0.143,112.0,160.0)
        tpdb.xyz[0][suc.top.c1inx[ssite]]=[cs]    
        
        fitinx=[suc.top.o1inx[ssite][0], suc.top.c1inx[ssite][0], suc.top.c2inx[ssite][0], \
                suc.top.c3inx[ssite][0], suc.top.c4inx[ssite][0]]
        
        done=False
        ncnt=1
        while not done and ncnt<10:
            rtor=random.random()*360.0-180.0
            c2s=buildFromIC(cg,os,cs,suc.top.bond[ssite]['C1-C2'],suc.top.angle[ssite]['O1-C1-C2'],rtor)
            tpdb.xyz[0][suc.top.c2inx[ssite]]=[c2s]      
            c3s=buildFromIC(os,cs,c2s,suc.top.bond[ssite]['C2-C3'],suc.top.angle[ssite]['C1-C2-C3'],suc.top.dihedral[ssite]['O1-C1-C2-C3'])
            tpdb.xyz[0][suc.top.c3inx[ssite]]=[c3s]
            c4s=buildFromIC(cs,c2s,c3s,suc.top.bond[ssite]['C3-C4'],suc.top.angle[ssite]['C2-C3-C4'],suc.top.dihedral[ssite]['C1-C2-C3-C4'])
            tpdb.xyz[0][suc.top.c4inx[ssite]]=[c4s]
            
            spdb.superpose(tpdb,atom_indices=fitinx)
            d=f.closest(suc,suc.top.excllist[ssite])
            if (d>0.2):
                done=True
            else:
                ncnt+=1
                
        return done
        
    def alignGlycerolToSucrose(f,glyc,isuc,ssite):
        gpdb=glyc.mol.pdb
        tpdb=copy.deepcopy(gpdb)

        csuc=f.sucrose[isuc].getatom(ssite,'C')
        osuc=f.sucrose[isuc].getatom(ssite,'O')
        
        og=osuc
        tpdb.xyz[0][glyc.top.o1inx]=[og]
        
        cg=buildFromIC(f.sucrose[isuc].mol.center(),csuc,og,0.143,112.0,160.0)
        tpdb.xyz[0][glyc.top.c1inx]=[cg]    

        fitinx=[glyc.top.o1inx[0], glyc.top.c1inx[0], glyc.top.c2inx[0], glyc.top.c3inx[0], glyc.top.o2inx[0], glyc.top.o3inx[0]]
                       
        done=False
        ncnt=1
        while not done and ncnt<10:
            rtor=random.random()*360.0-180.0
            c2g=buildFromIC(csuc,og,cg,glyc.top.bond['C1-C2'],glyc.top.angle['O1-C1-C2'],rtor)
            tpdb.xyz[0][glyc.top.c2inx]=[c2g]   
            c3g=buildFromIC(og,cg,c2g,glyc.top.bond['C2-C3'],glyc.top.angle['C1-C2-C3'],glyc.top.dihedral['O1-C1-C2-C3'])
            tpdb.xyz[0][glyc.top.c3inx]=[c3g]
            o3g=buildFromIC(cg,c2g,c3g,glyc.top.bond['C3-O3'],glyc.top.angle['C2-C3-O3'],glyc.top.dihedral['C1-C2-C3-O3'])
            tpdb.xyz[0][glyc.top.o3inx]=[o3g]
            o2g=buildFromIC(og,cg,c2g,glyc.top.bond['C2-O2'],glyc.top.angle['C1-C2-O2'],glyc.top.dihedral['O1-C1-C2-O2'])
            tpdb.xyz[0][glyc.top.o2inx]=[o2g]
            
            gpdb.superpose(tpdb,atom_indices=fitinx)
            d=f.closest(glyc,glyc.top.excllist)
            if (d>0.2):
                done=True
            else:
                ncnt+=1
                
        return done
         
    def addSucrose(f,mol,top,minx,igly=-1,site=''):
        isuc=len(f.sucrose)
        s=SucroseUnit(isuc+1,mol[minx],top[minx])
        
        add=False
        if (igly>=0):
            ok=f.alignSucroseToGlycerol(s,site,igly,'3')
            if (ok):
                f.glycerol[igly].connectTo('3',s,site)
                s.connectTo(site,f.glycerol[igly],'3')
                add=True
        else:
            add=True
            
        if (add):
            f.sucrose+=[s]    
            return isuc
        else:
            return -1
    
    def addGlycerol(f,mol,top,minx,isuc=-1,site=''):
        igly=len(f.glycerol)
        g=GlycerolUnit(igly+1,mol[minx],top[minx])
        
        add=False
        if (isuc>=0):
            ok=f.alignGlycerolToSucrose(g,isuc,site)
            if (ok):
                f.sucrose[isuc].connectTo(site,g,'1')
                g.connectTo('1',f.sucrose[isuc],site)
                add=True
        else: 
            add=True
            
        if (add):
            f.glycerol+=[g]
            return igly
        else:            
            return -1
        
    def molecularweight(f):
        totmw=len(f.sucrose)*f.mw['sucrose']+len(f.glycerol)*f.mw['glycerol']
        for g in f.glycerol:
            totmw-=f.mw['linkdel']*g.nconnect()
        return totmw
    
    def nglycerol(f):
        return len(f.glycerol)

    def nsucrose(f):
        return len(f.sucrose)
    
    def glycerolPerSucrose(f):
        return f.nglycerol()/f.nsucrose()

    def glycerolLinkFraction(f):
        sum=0.0
        for g in f.glycerol:
            sum+=(g.nconnect()-1)
        return sum/f.nglycerol()
    
    def generate(f):
        ires=1
        for s in f.sucrose:
            s.resid=ires
            ires+=2
        for g in f.glycerol:
            g.resid=ires
            ires+=1
        
    def write(f,fname):
        f.generate()
        
        fout=open(fname,"w")
        iatom=1
        for s in f.sucrose:
            p=s.mol.pdb
            t=p.topology
            for a in t.residue(0).atoms:
                if ('f1' in s.connect and (a.name == 'HO1')): 
                    continue
                elif ('f6' in s.connect and (a.name == 'HO6')):
                    continue
                printPDB(fout,a,iatom,s.resid,p.xyz[0][a.index],f.seg)
                iatom+=1
            
            for a in t.residue(1).atoms:
                if ('g2' in s.connect and (a.name == 'HO2')): 
                    continue
                elif ('g3' in s.connect and (a.name == 'HO3')):
                    continue
                elif ('g6' in s.connect and (a.name == 'HO6')):
                    continue
                printPDB(fout,a,iatom,s.resid+1,p.xyz[0][a.index],f.seg)
                iatom+=1
            
        for g in f.glycerol:
            p=g.mol.pdb
            t=p.topology
            for a in t.atoms:
                if ('1' in g.connect and (a.name == 'O1' or a.name == 'HO1')): 
                    continue
                elif ('3' in g.connect and (a.name == 'O3' or a.name == 'HO3')):
                    continue
            
                printPDB(fout,a,iatom,s.resid,p.xyz[0][a.index],f.seg)                    
                iatom+=1
        
        fout.write("TER\n")
        fout.write("END\n")
        fout.close()
        
    def patches(f):
        f.generate()
        
        for s in f.sucrose:
            print("SUCR:%s_%d:%s_%d" % (f.seg,s.resid,f.seg,s.resid+1))
            if 'f1' in s.connect:
                print("FG1%s:%s_%d:%s_%d" % (s.connectsite['f1'],f.seg,s.resid,f.seg,s.connect['f1'].resid))
            if 'f6' in s.connect:
                print("FG6%s:%s_%d:%s_%d" % (s.connectsite['f6'],f.seg,s.resid,f.seg,s.connect['f6'].resid))
            if 'g2' in s.connect:
                print("GG2%s:%s_%d:%s_%d" % (s.connectsite['g2'],f.seg,s.resid,f.seg,s.connect['g2'].resid))
            if 'g3' in s.connect:
                print("GG3%s:%s_%d:%s_%d" % (s.connectsite['g3'],f.seg,s.resid,f.seg,s.connect['g3'].resid))
            if 'g6' in s.connect:
                print("GG6%s:%s_%d:%s_%d" % (s.connectsite['g6'],f.seg,s.resid,f.seg,s.connect['g6'].resid))

# %%
def buildFromIC(a,b,c,r,theta,phi):   
    sinTheta=math.sin(theta*math.pi/180.0)
    cosTheta=math.cos(theta*math.pi/180.0)
    sinPhi=math.sin(phi*math.pi/180.0)
    cosPhi=math.cos(phi*math.pi/180.0)

    x=r*cosTheta
    y=r*cosPhi*sinTheta
    z=r*sinPhi*sinTheta
    
    a=np.array(a)
    b=np.array(b)
    c=np.array(c)
    
    ab=b-a
    bc=c-b
    bc=bc/np.linalg.norm(bc)
    
    n=np.cross(ab,bc)
    n=n/np.linalg.norm(n)
    ncbc=np.cross(n,bc)
    
    m=np.array([[bc[0],ncbc[0],n[0]], [bc[1],ncbc[1],n[1]], [bc[2],ncbc[2],n[2]]])
    d=np.matmul(m,np.array([-x,y,z]))+c
    return(d.tolist())
    
def minDist(m1,m2,hlist,list):
    mind=999999.0
    for h in hlist:
        xyz1=m1.mol.pdb.xyz[0][h]
        for l in list:
            xyz2=m2.mol.pdb.xyz[0][l]
            dx=xyz2-xyz1
            #numpy.sqrt(numpy.sum((a - b) ** 2, axis=0))
            #d=np.linalg.norm(dx)
            d=np.sum(dx**2)
            if (d<mind):
                mind=d
    return np.sqrt(mind)

def printPDB(fout,a,natom,nres,xyz,seg):
    fout.write("ATOM%7d %-4s %-4s%1s%-6s  %8.3f%8.3f%8.3f %5.2f%6.2f     %-4s\n" % \
              (natom,a.name,a.residue.name," ",nres,xyz[0]*10.0,xyz[1]*10.0,xyz[2]*10.0,1.0,0.0,seg))

# %% [markdown]
# Example for how to assemble a molecule manually:

# %%
f=Ficoll()

is1=f.addSucrose(smol,stop,0)
ig1=f.addGlycerol(gmol,gtop,0,is1,'f6')
ig2=f.addGlycerol(gmol,gtop,1,is1,'f1')
ig3=f.addGlycerol(gmol,gtop,0,is1,'g2')

is2=f.addSucrose(smol,stop,0,ig1,'f1')
is3=f.addSucrose(smol,stop,0,ig2,'g2')
is4=f.addSucrose(smol,stop,0,ig3,'f1')

ig4=f.addGlycerol(gmol,gtop,2,is4,'g2')

print(f.molecularweight())
print(f.glycerolPerSucrose())

f.write('ficoll-example.pdb')
f.patches()
# Out:
# 1611.477
# 1.0
# SUCR:PROF_1:PROF_2
# FG11:PROF_1:PROF_10
# FG61:PROF_1:PROF_9
# GG21:PROF_1:PROF_11
# SUCR:PROF_3:PROF_4
# FG13:PROF_3:PROF_9
# SUCR:PROF_5:PROF_6
# GG23:PROF_5:PROF_10
# SUCR:PROF_7:PROF_8
# FG13:PROF_7:PROF_11
# GG21:PROF_7:PROF_12

# %% [markdown]
# Automatic assembly

# %%
avgGlycerolPerSucrose=2.5
probGlycerolLink=0.6

targetMW = 30000     # in Dalton

prob={}
prob['f1']=0.3
prob['f6']=0.2
prob['g2']=0.25
prob['g6']=0.3
prob['g3']=0.05

def randomSite(p):
    v=random.random()
    sum=0.0
    for s in p:
        sum+=p[s]
        if (v<sum):
            return s
    return ''

# %%
f=Ficoll()

isuc=f.addSucrose(smol,stop,random.randrange(len(smol)))
islist=[isuc]
while(f.molecularweight()<targetMW and len(islist)>0):
    iglist=[]
    random.shuffle(islist)
    for s in islist:
        cnt=0
        while (f.glycerolPerSucrose()<avgGlycerolPerSucrose and cnt<10 and f.molecularweight()<targetMW):
            rsite=randomSite(prob)
                #print(rsite)
            if rsite in f.sucrose[s].connect:
                cnt+=1
                continue
            igly=f.addGlycerol(gmol,gtop,random.randrange(len(gmol)),s,rsite)
            if (igly>=0): iglist+=[igly]
        
    print("added %3d glycerols : mw %10.2lf : %5.2lf glyc/suc : %5.2lf links/glyc" %\
          (len(iglist), f.molecularweight(), f.glycerolPerSucrose(), f.glycerolLinkFraction()))

    islist=[]
    random.shuffle(iglist)
    for g in iglist:
        if (random.random()<probGlycerolLink*1.20 and f.molecularweight()<targetMW):
            rsite=randomSite(prob)
            isuc=f.addSucrose(smol,stop,random.randrange(len(smol)),g,rsite)
            if (isuc>=0): islist+=[isuc]
            
    if (len(islist)==0 and f.molecularweight()<targetMW):
        #print(f'add at least one')
        g=iglist[random.randrange(len(iglist))]
        rsite=randomSite(prob)
        isuc=f.addSucrose(smol[random.randrange(len(smol))],g,rsite)
        if (isuc>=0): islist+=[isuc]

    print("added %3d sucroses  : mw %10.2lf : %5.2lf glyc/suc : %5.2lf links/glyc" %\
          (len(islist), f.molecularweight(), f.glycerolPerSucrose(), f.glycerolLinkFraction()))
# Out:
# added   3 glycerols : mw     564.54 :  3.00 glyc/suc :  0.00 links/glyc
# added   2 sucroses  : mw    1213.11 :  1.00 glyc/suc :  0.67 links/glyc
# added   5 glycerols : mw    1583.51 :  2.67 glyc/suc :  0.25 links/glyc
# added   3 sucroses  : mw    2556.37 :  1.33 glyc/suc :  0.62 links/glyc
# added   7 glycerols : mw    3074.93 :  2.50 glyc/suc :  0.33 links/glyc
# added   4 sucroses  : mw    4372.07 :  1.50 glyc/suc :  0.60 links/glyc
# added  10 glycerols : mw    5112.87 :  2.50 glyc/suc :  0.36 links/glyc
# added   5 sucroses  : mw    6734.29 :  1.67 glyc/suc :  0.56 links/glyc
# added  13 glycerols : mw    7697.33 :  2.53 glyc/suc :  0.37 links/glyc
# added   9 sucroses  : mw   10615.90 :  1.58 glyc/suc :  0.61 links/glyc
# added  22 glycerols : mw   12245.66 :  2.50 glyc/suc :  0.38 links/glyc
# added  10 sucroses  : mw   15488.51 :  1.76 glyc/suc :  0.55 links/glyc
# added  25 glycerols : mw   17340.51 :  2.50 glyc/suc :  0.39 links/glyc
# added  14 sucroses  : mw   21880.51 :  1.77 glyc/suc :  0.55 links/glyc
# added  35 glycerols : mw   24473.30 :  2.50 glyc/suc :  0.39 links/glyc
# added  21 sucroses  : mw   31283.30 :  1.74 glyc/suc :  0.57 links/glyc
# added  53 glycerols : mw   35209.53 :  2.51 glyc/suc :  0.39 links/glyc
# added  29 sucroses  : mw   44613.81 :  1.77 glyc/suc :  0.56 links/glyc
# added  72 glycerols : mw   49947.56 :  2.50 glyc/suc :  0.40 links/glyc
# added  41 sucroses  : mw   63243.26 :  1.76 glyc/suc :  0.56 links/glyc
# added  92 glycerols : mw   70058.61 :  2.42 glyc/suc :  0.41 links/glyc
# added   0 sucroses  : mw   70058.61 :  2.42 glyc/suc :  0.41 links/glyc

# %% [markdown]
# Saving molecule

# %%
f.write('ficoll.pdb')

# %% [markdown]
# Writing out patches

# %%
f.patches()
# Out:
# SUCR:PROF_1:PROF_2
# FG11:PROF_1:PROF_279
# FG61:PROF_1:PROF_281
# GG21:PROF_1:PROF_280
# SUCR:PROF_3:PROF_4
# FG11:PROF_3:PROF_285
# GG21:PROF_3:PROF_286
# GG63:PROF_3:PROF_279
# SUCR:PROF_5:PROF_6
# FG11:PROF_5:PROF_282
# FG61:PROF_5:PROF_284
# GG21:PROF_5:PROF_283
# GG63:PROF_5:PROF_281
# SUCR:PROF_7:PROF_8
# FG11:PROF_7:PROF_288
# FG61:PROF_7:PROF_287
# GG21:PROF_7:PROF_289
# GG63:PROF_7:PROF_282
# SUCR:PROF_9:PROF_10
# FG13:PROF_9:PROF_283
# FG61:PROF_9:PROF_291
# GG61:PROF_9:PROF_290
# SUCR:PROF_11:PROF_12
# FG11:PROF_11:PROF_292
# GG21:PROF_11:PROF_293
# GG63:PROF_11:PROF_284
# SUCR:PROF_13:PROF_14
# FG11:PROF_13:PROF_296
# FG61:PROF_13:PROF_298
# GG21:PROF_13:PROF_297
# GG63:PROF_13:PROF_290
# SUCR:PROF_15:PROF_16
# FG63:PROF_15:PROF_289
# GG21:PROF_15:PROF_294
# GG61:PROF_15:PROF_295
# SUCR:PROF_17:PROF_18
# FG13:PROF_17:PROF_291
# FG61:PROF_17:PROF_299
# GG61:PROF_17:PROF_300
# SUCR:PROF_19:PROF_20
# FG11:PROF_19:PROF_303
# FG61:PROF_19:PROF_302
# GG21:PROF_19:PROF_301
# GG63:PROF_19:PROF_287
# SUCR:PROF_21:PROF_22
# FG11:PROF_21:PROF_314
# FG61:PROF_21:PROF_315
# GG21:PROF_21:PROF_313
# GG63:PROF_21:PROF_302
# SUCR:PROF_23:PROF_24
# FG11:PROF_23:PROF_304
# FG61:PROF_23:PROF_305
# GG21:PROF_23:PROF_306
# GG63:PROF_23:PROF_295
# SUCR:PROF_25:PROF_26
# FG13:PROF_25:PROF_300
# GG61:PROF_25:PROF_316
# SUCR:PROF_27:PROF_28
# FG13:PROF_27:PROF_294
# FG61:PROF_27:PROF_309
# GG21:PROF_27:PROF_307
# GG61:PROF_27:PROF_308
# SUCR:PROF_29:PROF_30
# FG11:PROF_29:PROF_310
# FG61:PROF_29:PROF_311
# GG21:PROF_29:PROF_312
# GG63:PROF_29:PROF_301
# SUCR:PROF_31:PROF_32
# FG11:PROF_31:PROF_322
# FG61:PROF_31:PROF_321
# GG21:PROF_31:PROF_320
# GG63:PROF_31:PROF_314
# SUCR:PROF_33:PROF_34
# FG13:PROF_33:PROF_316
# SUCR:PROF_35:PROF_36
# FG11:PROF_35:PROF_335
# FG63:PROF_35:PROF_311
# GG21:PROF_35:PROF_336
# GG61:PROF_35:PROF_334
# SUCR:PROF_37:PROF_38
# FG13:PROF_37:PROF_313
# GG21:PROF_37:PROF_330
# GG61:PROF_37:PROF_329
# SUCR:PROF_39:PROF_40
# FG11:PROF_39:PROF_323
# FG61:PROF_39:PROF_325
# GG23:PROF_39:PROF_305
# GG61:PROF_39:PROF_324
# SUCR:PROF_41:PROF_42
# FG13:PROF_41:PROF_309
# GG21:PROF_41:PROF_338
# GG61:PROF_41:PROF_337
# SUCR:PROF_43:PROF_44
# FG11:PROF_43:PROF_333
# FG63:PROF_43:PROF_312
# GG21:PROF_43:PROF_332
# GG61:PROF_43:PROF_331
# SUCR:PROF_45:PROF_46
# FG13:PROF_45:PROF_304
# FG61:PROF_45:PROF_326
# GG21:PROF_45:PROF_328
# GG61:PROF_45:PROF_327
# SUCR:PROF_47:PROF_48
# FG11:PROF_47:PROF_318
# FG61:PROF_47:PROF_317
# GG21:PROF_47:PROF_319
# GG63:PROF_47:PROF_310
# SUCR:PROF_49:PROF_50
# FG11:PROF_49:PROF_346
# FG63:PROF_49:PROF_334
# GG21:PROF_49:PROF_348
# GG61:PROF_49:PROF_347
# SUCR:PROF_51:PROF_52
# FG11:PROF_51:PROF_344
# FG61:PROF_51:PROF_345
# GG23:PROF_51:PROF_331
# SUCR:PROF_53:PROF_54
# FG11:PROF_53:PROF_355
# FG61:PROF_53:PROF_356
# GG23:PROF_53:PROF_336
# GG61:PROF_53:PROF_357
# SUCR:PROF_55:PROF_56
# FG13:PROF_55:PROF_322
# FG61:PROF_55:PROF_353
# GG21:PROF_55:PROF_352
# GG61:PROF_55:PROF_354
# SUCR:PROF_57:PROF_58
# FG63:PROF_57:PROF_319
# GG21:PROF_57:PROF_363
# SUCR:PROF_59:PROF_60
# FG13:PROF_59:PROF_318
# FG61:PROF_59:PROF_361
# GG61:PROF_59:PROF_362
# SUCR:PROF_61:PROF_62
# FG13:PROF_61:PROF_326
# FG61:PROF_61:PROF_343
# GG61:PROF_61:PROF_342
# SUCR:PROF_63:PROF_64
# FG13:PROF_63:PROF_325
# FG61:PROF_63:PROF_358
# GG21:PROF_63:PROF_360
# GG61:PROF_63:PROF_359
# SUCR:PROF_65:PROF_66
# FG11:PROF_65:PROF_339
# FG61:PROF_65:PROF_340
# GG21:PROF_65:PROF_341
# GG63:PROF_65:PROF_327
# SUCR:PROF_67:PROF_68
# FG11:PROF_67:PROF_350
# FG63:PROF_67:PROF_330
# GG21:PROF_67:PROF_351
# GG61:PROF_67:PROF_349
# SUCR:PROF_69:PROF_70
# FG13:PROF_69:PROF_345
# FG61:PROF_69:PROF_377
# GG21:PROF_69:PROF_378
# SUCR:PROF_71:PROF_72
# FG13:PROF_71:PROF_354
# FG61:PROF_71:PROF_389
# GG21:PROF_71:PROF_388
# GG61:PROF_71:PROF_387
# SUCR:PROF_73:PROF_74
# FG13:PROF_73:PROF_348
# FG61:PROF_73:PROF_385
# GG21:PROF_73:PROF_386
# GG61:PROF_73:PROF_384
# SUCR:PROF_75:PROF_76
# FG13:PROF_75:PROF_350
# SUCR:PROF_77:PROF_78
# FG11:PROF_77:PROF_395
# FG61:PROF_77:PROF_393
# GG21:PROF_77:PROF_394
# GG63:PROF_77:PROF_340
# SUCR:PROF_79:PROF_80
# FG11:PROF_79:PROF_396
# FG61:PROF_79:PROF_397
# GG21:PROF_79:PROF_398
# GG63:PROF_79:PROF_342
# SUCR:PROF_81:PROF_82
# FG13:PROF_81:PROF_363
# FG61:PROF_81:PROF_390
# GG21:PROF_81:PROF_391
# GG61:PROF_81:PROF_392
# SUCR:PROF_83:PROF_84
# FG11:PROF_83:PROF_380
# FG61:PROF_83:PROF_379
# GG23:PROF_83:PROF_355
# SUCR:PROF_85:PROF_86
# FG11:PROF_85:PROF_367
# FG61:PROF_85:PROF_366
# GG23:PROF_85:PROF_347
# GG61:PROF_85:PROF_368
# SUCR:PROF_87:PROF_88
# FG11:PROF_87:PROF_373
# FG63:PROF_87:PROF_359
# GG21:PROF_87:PROF_374
# GG61:PROF_87:PROF_372
# SUCR:PROF_89:PROF_90
# FG13:PROF_89:PROF_357
# FG61:PROF_89:PROF_371
# GG21:PROF_89:PROF_369
# GG61:PROF_89:PROF_370
# SUCR:PROF_91:PROF_92
# FG13:PROF_91:PROF_344
# FG61:PROF_91:PROF_364
# GG61:PROF_91:PROF_365
# SUCR:PROF_93:PROF_94
# FG13:PROF_93:PROF_339
# FG61:PROF_93:PROF_381
# GG21:PROF_93:PROF_382
# GG61:PROF_93:PROF_383
# SUCR:PROF_95:PROF_96
# FG13:PROF_95:PROF_356
# GG21:PROF_95:PROF_375
# GG61:PROF_95:PROF_376
# SUCR:PROF_97:PROF_98
# FG11:PROF_97:PROF_399
# FG63:PROF_97:PROF_364
# GG21:PROF_97:PROF_401
# GG61:PROF_97:PROF_400
# SUCR:PROF_99:PROF_100
# FG11:PROF_99:PROF_417
# FG61:PROF_99:PROF_418
# GG21:PROF_99:PROF_416
# GG63:PROF_99:PROF_372
# SUCR:PROF_101:PROF_102
# FG11:PROF_101:PROF_440
# FG61:PROF_101:PROF_441
# GG23:PROF_101:PROF_391
# GG61:PROF_101:PROF_439
# SUCR:PROF_103:PROF_104
# FG11:PROF_103:PROF_419
# FG63:PROF_103:PROF_365
# GG21:PROF_103:PROF_420
# GG61:PROF_103:PROF_421
# SUCR:PROF_105:PROF_106
# FG11:PROF_105:PROF_409
# FG61:PROF_105:PROF_410
# GG23:PROF_105:PROF_388
# GG61:PROF_105:PROF_408
# SUCR:PROF_107:PROF_108
# FG11:PROF_107:PROF_423
# FG61:PROF_107:PROF_422
# GG21:PROF_107:PROF_424
# GG63:PROF_107:PROF_382
# SUCR:PROF_109:PROF_110
# FG11:PROF_109:PROF_407
# FG61:PROF_109:PROF_406
# GG21:PROF_109:PROF_405
# GG63:PROF_109:PROF_368
# SUCR:PROF_111:PROF_112
# FG61:PROF_111:PROF_415
# GG23:PROF_111:PROF_366
# GG61:PROF_111:PROF_414
# SUCR:PROF_113:PROF_114
# FG13:PROF_113:PROF_378
# SUCR:PROF_115:PROF_116
# FG13:PROF_115:PROF_396
# FG61:PROF_115:PROF_428
# GG21:PROF_115:PROF_430
# GG61:PROF_115:PROF_429
# SUCR:PROF_117:PROF_118
# FG11:PROF_117:PROF_443
# FG61:PROF_117:PROF_442
# GG23:PROF_117:PROF_397
# GG61:PROF_117:PROF_444
# SUCR:PROF_119:PROF_120
# FG13:PROF_119:PROF_392
# GG21:PROF_119:PROF_451
# SUCR:PROF_121:PROF_122
# FG13:PROF_121:PROF_377
# FG61:PROF_121:PROF_427
# GG21:PROF_121:PROF_425
# GG61:PROF_121:PROF_426
# SUCR:PROF_123:PROF_124
# FG11:PROF_123:PROF_434
# FG63:PROF_123:PROF_383
# GG21:PROF_123:PROF_433
# GG61:PROF_123:PROF_435
# SUCR:PROF_125:PROF_126
# FG11:PROF_125:PROF_436
# FG61:PROF_125:PROF_437
# GG21:PROF_125:PROF_438
# GG63:PROF_125:PROF_375
# SUCR:PROF_127:PROF_128
# FG13:PROF_127:PROF_390
# FG61:PROF_127:PROF_446
# GG21:PROF_127:PROF_447
# GG61:PROF_127:PROF_445
# SUCR:PROF_129:PROF_130
# FG11:PROF_129:PROF_449
# FG61:PROF_129:PROF_448
# GG23:PROF_129:PROF_395
# GG61:PROF_129:PROF_450
# SUCR:PROF_131:PROF_132
# FG11:PROF_131:PROF_412
# FG61:PROF_131:PROF_413
# GG21:PROF_131:PROF_411
# GG63:PROF_131:PROF_371
# SUCR:PROF_133:PROF_134
# FG13:PROF_133:PROF_393
# GG21:PROF_133:PROF_431
# GG61:PROF_133:PROF_432
# SUCR:PROF_135:PROF_136
# GG23:PROF_135:PROF_376
# SUCR:PROF_137:PROF_138
# FG11:PROF_137:PROF_403
# FG63:PROF_137:PROF_398
# GG21:PROF_137:PROF_402
# GG61:PROF_137:PROF_404
# SUCR:PROF_139:PROF_140
# FG11:PROF_139:PROF_516
# FG63:PROF_139:PROF_450
# GG21:PROF_139:PROF_517
# GG61:PROF_139:PROF_515
# SUCR:PROF_141:PROF_142
# FG11:PROF_141:PROF_514
# FG61:PROF_141:PROF_513
# GG21:PROF_141:PROF_512
# GG63:PROF_141:PROF_424
# SUCR:PROF_143:PROF_144
# FG63:PROF_143:PROF_411
# SUCR:PROF_145:PROF_146
# FG11:PROF_145:PROF_507
# FG61:PROF_145:PROF_508
# GG63:PROF_145:PROF_440
# SUCR:PROF_147:PROF_148
# FG11:PROF_147:PROF_485
# FG63:PROF_147:PROF_400
# GG61:PROF_147:PROF_484
# SUCR:PROF_149:PROF_150
# FG11:PROF_149:PROF_492
# FG61:PROF_149:PROF_494
# GG23:PROF_149:PROF_449
# GG61:PROF_149:PROF_493
# SUCR:PROF_151:PROF_152
# FG11:PROF_151:PROF_477
# FG63:PROF_151:PROF_401
# GG21:PROF_151:PROF_475
# GG61:PROF_151:PROF_476
# SUCR:PROF_153:PROF_154
# FG11:PROF_153:PROF_488
# FG61:PROF_153:PROF_486
# GG23:PROF_153:PROF_447
# GG61:PROF_153:PROF_487
# SUCR:PROF_155:PROF_156
# FG11:PROF_155:PROF_481
# FG61:PROF_155:PROF_482
# GG21:PROF_155:PROF_483
# GG63:PROF_155:PROF_429
# SUCR:PROF_157:PROF_158
# FG11:PROF_157:PROF_500
# FG61:PROF_157:PROF_498
# GG21:PROF_157:PROF_499
# GG63:PROF_157:PROF_426
# SUCR:PROF_159:PROF_160
# FG63:PROF_159:PROF_407
# GG21:PROF_159:PROF_523
# SUCR:PROF_161:PROF_162
# FG13:PROF_161:PROF_437
# FG61:PROF_161:PROF_522
# GG21:PROF_161:PROF_521
# GG61:PROF_161:PROF_520
# SUCR:PROF_163:PROF_164
# FG61:PROF_163:PROF_519
# GG23:PROF_163:PROF_441
# GG61:PROF_163:PROF_518
# SUCR:PROF_165:PROF_166
# FG11:PROF_165:PROF_458
# FG61:PROF_165:PROF_460
# GG23:PROF_165:PROF_439
# GG61:PROF_165:PROF_459
# SUCR:PROF_167:PROF_168
# FG11:PROF_167:PROF_469
# FG63:PROF_167:PROF_413
# GG21:PROF_167:PROF_470
# GG61:PROF_167:PROF_471
# SUCR:PROF_169:PROF_170
# FG11:PROF_169:PROF_456
# FG61:PROF_169:PROF_455
# GG23:PROF_169:PROF_412
# GG61:PROF_169:PROF_457
# SUCR:PROF_171:PROF_172
# FG11:PROF_171:PROF_472
# FG61:PROF_171:PROF_474
# GG23:PROF_171:PROF_403
# GG61:PROF_171:PROF_473
# SUCR:PROF_173:PROF_174
# FG13:PROF_173:PROF_442
# GG21:PROF_173:PROF_465
# GG61:PROF_173:PROF_464
# SUCR:PROF_175:PROF_176
# FG13:PROF_175:PROF_428
# SUCR:PROF_177:PROF_178
# FG11:PROF_177:PROF_496
# FG61:PROF_177:PROF_497
# GG23:PROF_177:PROF_423
# GG61:PROF_177:PROF_495
# SUCR:PROF_179:PROF_180
# FG13:PROF_179:PROF_417
# FG61:PROF_179:PROF_463
# GG21:PROF_179:PROF_461
# GG61:PROF_179:PROF_462
# SUCR:PROF_181:PROF_182
# GG63:PROF_181:PROF_410
# SUCR:PROF_183:PROF_184
# FG11:PROF_183:PROF_503
# FG61:PROF_183:PROF_501
# GG23:PROF_183:PROF_434
# GG61:PROF_183:PROF_502
# SUCR:PROF_185:PROF_186
# FG13:PROF_185:PROF_433
# FG61:PROF_185:PROF_505
# GG21:PROF_185:PROF_506
# GG61:PROF_185:PROF_504
# SUCR:PROF_187:PROF_188
# FG11:PROF_187:PROF_490
# FG61:PROF_187:PROF_489
# GG23:PROF_187:PROF_406
# GG61:PROF_187:PROF_491
# SUCR:PROF_189:PROF_190
# FG11:PROF_189:PROF_509
# FG61:PROF_189:PROF_511
# GG21:PROF_189:PROF_510
# GG63:PROF_189:PROF_421
# SUCR:PROF_191:PROF_192
# FG11:PROF_191:PROF_467
# FG63:PROF_191:PROF_451
# GG21:PROF_191:PROF_468
# GG61:PROF_191:PROF_466
# SUCR:PROF_193:PROF_194
# FG11:PROF_193:PROF_454
# FG63:PROF_193:PROF_432
# GG21:PROF_193:PROF_453
# GG61:PROF_193:PROF_452
# SUCR:PROF_195:PROF_196
# FG13:PROF_195:PROF_420
# FG61:PROF_195:PROF_480
# GG21:PROF_195:PROF_478
# GG61:PROF_195:PROF_479
# SUCR:PROF_197:PROF_198
# FG11:PROF_197:PROF_561
# FG61:PROF_197:PROF_560
# GG23:PROF_197:PROF_458
# GG61:PROF_197:PROF_562
# SUCR:PROF_199:PROF_200
# FG11:PROF_199:PROF_594
# FG61:PROF_199:PROF_595
# GG23:PROF_199:PROF_482
# GG61:PROF_199:PROF_593
# SUCR:PROF_201:PROF_202
# FG13:PROF_201:PROF_472
# FG61:PROF_201:PROF_588
# GG21:PROF_201:PROF_589
# GG61:PROF_201:PROF_587
# SUCR:PROF_203:PROF_204
# FG11:PROF_203:PROF_606
# FG61:PROF_203:PROF_604
# GG23:PROF_203:PROF_465
# GG61:PROF_203:PROF_605
# SUCR:PROF_205:PROF_206
# FG11:PROF_205:PROF_608
# FG61:PROF_205:PROF_607
# GG21:PROF_205:PROF_609
# GG63:PROF_205:PROF_506
# SUCR:PROF_207:PROF_208
# FG11:PROF_207:PROF_553
# FG61:PROF_207:PROF_554
# GG23:PROF_207:PROF_523
# SUCR:PROF_209:PROF_210
# GG23:PROF_209:PROF_514
# SUCR:PROF_211:PROF_212
# FG13:PROF_211:PROF_488
# FG61:PROF_211:PROF_576
# GG21:PROF_211:PROF_577
# GG61:PROF_211:PROF_578
# SUCR:PROF_213:PROF_214
# GG63:PROF_213:PROF_495
# SUCR:PROF_215:PROF_216
# FG11:PROF_215:PROF_535
# FG61:PROF_215:PROF_536
# GG63:PROF_215:PROF_474
# SUCR:PROF_217:PROF_218
# FG13:PROF_217:PROF_505
# FG61:PROF_217:PROF_552
# GG21:PROF_217:PROF_551
# SUCR:PROF_219:PROF_220
# FG11:PROF_219:PROF_524
# FG63:PROF_219:PROF_471
# GG61:PROF_219:PROF_525
# SUCR:PROF_221:PROF_222
# FG11:PROF_221:PROF_567
# FG61:PROF_221:PROF_566
# GG23:PROF_221:PROF_485
# GG61:PROF_221:PROF_568
# SUCR:PROF_223:PROF_224
# FG11:PROF_223:PROF_600
# FG63:PROF_223:PROF_509
# GG61:PROF_223:PROF_599
# SUCR:PROF_225:PROF_226
# FG11:PROF_225:PROF_569
# FG63:PROF_225:PROF_484
# GG21:PROF_225:PROF_571
# GG61:PROF_225:PROF_570
# SUCR:PROF_227:PROF_228
# FG11:PROF_227:PROF_539
# FG61:PROF_227:PROF_537
# GG21:PROF_227:PROF_538
# GG63:PROF_227:PROF_487
# SUCR:PROF_229:PROF_230
# FG13:PROF_229:PROF_492
# FG61:PROF_229:PROF_532
# GG21:PROF_229:PROF_533
# GG61:PROF_229:PROF_534
# SUCR:PROF_231:PROF_232
# FG11:PROF_231:PROF_555
# GG21:PROF_231:PROF_556
# GG63:PROF_231:PROF_507
# SUCR:PROF_233:PROF_234
# FG11:PROF_233:PROF_540
# FG61:PROF_233:PROF_541
# GG63:PROF_233:PROF_498
# SUCR:PROF_235:PROF_236
# GG63:PROF_235:PROF_469
# SUCR:PROF_237:PROF_238
# FG11:PROF_237:PROF_584
# FG61:PROF_237:PROF_586
# GG23:PROF_237:PROF_502
# GG61:PROF_237:PROF_585
# SUCR:PROF_239:PROF_240
# FG13:PROF_239:PROF_486
# FG61:PROF_239:PROF_614
# GG21:PROF_239:PROF_615
# SUCR:PROF_241:PROF_242
# FG11:PROF_241:PROF_558
# FG63:PROF_241:PROF_481
# GG21:PROF_241:PROF_557
# GG61:PROF_241:PROF_559
# SUCR:PROF_243:PROF_244
# GG23:PROF_243:PROF_510
# SUCR:PROF_245:PROF_246
# FG11:PROF_245:PROF_545
# FG61:PROF_245:PROF_547
# GG21:PROF_245:PROF_546
# GG63:PROF_245:PROF_521
# SUCR:PROF_247:PROF_248
# FG11:PROF_247:PROF_572
# FG61:PROF_247:PROF_573
# GG63:PROF_247:PROF_470
# SUCR:PROF_249:PROF_250
# FG13:PROF_249:PROF_454
# FG61:PROF_249:PROF_580
# GG21:PROF_249:PROF_579
# SUCR:PROF_251:PROF_252
# GG23:PROF_251:PROF_508
# SUCR:PROF_253:PROF_254
# FG13:PROF_253:PROF_504
# FG61:PROF_253:PROF_549
# GG21:PROF_253:PROF_550
# GG61:PROF_253:PROF_548
# SUCR:PROF_255:PROF_256
# FG13:PROF_255:PROF_496
# FG61:PROF_255:PROF_531
# GG21:PROF_255:PROF_530
# GG61:PROF_255:PROF_529
# SUCR:PROF_257:PROF_258
# FG11:PROF_257:PROF_596
# FG63:PROF_257:PROF_518
# GG21:PROF_257:PROF_598
# GG61:PROF_257:PROF_597
# SUCR:PROF_259:PROF_260
# GG23:PROF_259:PROF_480
# SUCR:PROF_261:PROF_262
# FG13:PROF_261:PROF_468
# FG61:PROF_261:PROF_563
# GG21:PROF_261:PROF_564
# GG61:PROF_261:PROF_565
# SUCR:PROF_263:PROF_264
# FG11:PROF_263:PROF_590
# FG61:PROF_263:PROF_591
# GG21:PROF_263:PROF_592
# GG63:PROF_263:PROF_522
# SUCR:PROF_265:PROF_266
# FG13:PROF_265:PROF_466
# FG61:PROF_265:PROF_526
# GG21:PROF_265:PROF_528
# GG61:PROF_265:PROF_527
# SUCR:PROF_267:PROF_268
# FG11:PROF_267:PROF_603
# FG63:PROF_267:PROF_457
# GG21:PROF_267:PROF_602
# GG61:PROF_267:PROF_601
# SUCR:PROF_269:PROF_270
# FG13:PROF_269:PROF_512
# FG61:PROF_269:PROF_542
# GG21:PROF_269:PROF_543
# GG61:PROF_269:PROF_544
# SUCR:PROF_271:PROF_272
# FG61:PROF_271:PROF_612
# GG23:PROF_271:PROF_453
# GG61:PROF_271:PROF_613
# SUCR:PROF_273:PROF_274
# FG11:PROF_273:PROF_581
# FG61:PROF_273:PROF_583
# GG21:PROF_273:PROF_582
# GG63:PROF_273:PROF_478
# SUCR:PROF_275:PROF_276
# FG11:PROF_275:PROF_574
# GG23:PROF_275:PROF_501
# GG61:PROF_275:PROF_575
# SUCR:PROF_277:PROF_278
# FG11:PROF_277:PROF_610
# GG21:PROF_277:PROF_611
# GG63:PROF_277:PROF_490

# %%
import mdtraj as md
import nglview as nv

viewpdb=md.load_pdb("ficoll.pdb")

view = nv.NGLWidget(nv.MDTrajTrajectory(viewpdb))
#view.clear_representations()
#view.add_licorice('',color="blue")
#view.add_licorice(':B',color="blue")
#view.add_licorice(f'{selectresidue}:B',color="green")
#view.add_spacefill(f'{selectresidue}:B and .CA', radius="0.5", color="red")
view.camera='orthographic'

view
