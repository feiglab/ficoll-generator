# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/feiglab/ficoll-generator/blob/main/BuildFicoll.ipynb)

# %% [markdown]
# # Building Ficoll Polymers

# %% [markdown]
# This notebook assembles Ficoll polymers of arbitrary size based on given input parameters

# %% [markdown]
# We begin by loading modules.

# %%
import os
import sys
import numpy as np
import math
import copy
import random

# %%
import subprocess

pkgs = [ i.split('==')[0].lower() for i in subprocess.getoutput('pip list --format=freeze').splitlines() ]
if not 'mdtraj' in pkgs:
    print('MDTraj is not available. Trying to install package.\n')
    # !pip install mdtraj

# %%
import mdtraj as md

# %% [markdown]
# Let's begin by reading glycerol and sucrose molecules in a few different conformations.
#
# The following cell downloads the PDB files from github if they are not available.

# %%
from pathlib import Path
if not Path("input/glycerol1.pdb").exists():
    # !mkdir -p input
    # !wget https://github.com/feiglab/ficoll-generator/blob/main/input/glycerol1.pdb -O input/glycerol1.pdb
    # !wget https://github.com/feiglab/ficoll-generator/blob/main/input/glycerol2.pdb -O input/glycerol2.pdb
    # !wget https://github.com/feiglab/ficoll-generator/blob/main/input/glycerol3.pdb -O input/glycerol3.pdb
    # !wget https://github.com/feiglab/ficoll-generator/blob/main/input/sucrose1.pdb -O input/sucrose1.pdb
    # !wget https://github.com/feiglab/ficoll-generator/blob/main/input/sucrose2.pdb -O input/sucrose2.pdb
    # !wget https://github.com/feiglab/ficoll-generator/blob/main/input/sucrose3.pdb -O input/sucrose3.pdb
    # !wget https://github.com/feiglab/ficoll-generator/blob/main/input/sucrose4.pdb -O input/sucrose4.pdb

# %%
class Molecule:
    def __init__(m,fname):
        m.xyz={}
        m.pdb=md.load_pdb(fname)
        m.mapatom={}
        for n in m.pdb.topology.atoms:
            m.mapatom[f'{n.residue.name}:{n.name}']=n.index
            
    def center(m):
        return md.compute_center_of_mass(m.pdb)[0]
        
    def getatom(m,key):
        return np.array(m.pdb.xyz[0][m.mapatom[key]])
        
gmol=[]
gmol+=[Molecule('input/glycerol1.pdb')]
gmol+=[Molecule('input/glycerol2.pdb')]
gmol+=[Molecule('input/glycerol3.pdb')]

smol=[]
smol+=[Molecule('input/sucrose1.pdb')]
smol+=[Molecule('input/sucrose2.pdb')]
smol+=[Molecule('input/sucrose3.pdb')]
smol+=[Molecule('input/sucrose4.pdb')]

# %%
def bond(mol,res,a1,a2):
    inx1=mol.pdb.topology.select(f"resname {res} and name {a1}")
    inx2=mol.pdb.topology.select(f"resname {res} and name {a2}")
    
    b=mol.pdb.xyz[0][inx1]-mol.pdb.xyz[0][inx2]

    return np.linalg.norm(b)

def angle(mol,res,a1,a2,a3):
    inx1=mol.pdb.topology.select(f"resname {res} and name {a1}")
    inx2=mol.pdb.topology.select(f"resname {res} and name {a2}")
    inx3=mol.pdb.topology.select(f"resname {res} and name {a3}")

    b1=mol.pdb.xyz[0][inx1]-mol.pdb.xyz[0][inx2]
    b2=mol.pdb.xyz[0][inx3]-mol.pdb.xyz[0][inx2]

    return math.acos(np.dot(b1[0],b2[0])/(np.linalg.norm(b1)*np.linalg.norm(b2)))*180.0/math.pi

def dihedral(mol,res,a1,a2,a3,a4):
    inx1=mol.pdb.topology.select(f"resname {res} and name {a1}")
    inx2=mol.pdb.topology.select(f"resname {res} and name {a2}")
    inx3=mol.pdb.topology.select(f"resname {res} and name {a3}")
    inx4=mol.pdb.topology.select(f"resname {res} and name {a4}")

    b1=mol.pdb.xyz[0][inx1]-mol.pdb.xyz[0][inx2]
    b2=mol.pdb.xyz[0][inx3]-mol.pdb.xyz[0][inx2]
    b3=mol.pdb.xyz[0][inx4]-mol.pdb.xyz[0][inx3]

    b0xb1 = np.cross(b1[0], b2[0])
    b1xb2 = np.cross(b3[0], b2[0])
    b0xb1_x_b1xb2 = np.cross(b0xb1, b1xb2)

    y = np.dot(b0xb1_x_b1xb2, b2[0])*(1.0/np.linalg.norm(b2))
    x = np.dot(b0xb1, b1xb2)

    return np.degrees(np.arctan2(y, x))

# %%
class GlycerolTopology:
    def __init__(g,mol):
        g.hlist=mol.pdb.topology.select("not type H")
        g.o1inx=mol.pdb.topology.select("name O1")
        g.c1inx=mol.pdb.topology.select("name C1")
        g.c2inx=mol.pdb.topology.select("name C2")
        g.c3inx=mol.pdb.topology.select("name C3")
        g.o3inx=mol.pdb.topology.select("name O3")
        g.o2inx=mol.pdb.topology.select("name O2")
        g.excllist=mol.pdb.topology.select("not name O1 and not name C1 and not type H")
        g.calcIC(mol)

    def calcIC(g,mol):
        g.bond={}
        g.bond['O1-C1']=bond(mol,"MGL","O1","C1")
        g.bond['C1-C2']=bond(mol,"MGL","C1","C2")
        g.bond['C2-C3']=bond(mol,"MGL","C2","C3")
        g.bond['C3-O3']=bond(mol,"MGL","C3","O3")
        g.bond['C2-O2']=bond(mol,"MGL","C2","O2")
        
        g.angle={}
        g.angle['O1-C1-C2']=angle(mol,"MGL","O1","C1","C2")
        g.angle['C1-C2-C3']=angle(mol,"MGL","C1","C2","C3")
        g.angle['C2-C3-O3']=angle(mol,"MGL","C2","C3","O3")
        g.angle['C1-C2-O2']=angle(mol,"MGL","C1","C2","O2") 
        
        g.dihedral={}
        g.dihedral['O1-C1-C2-C3']=dihedral(mol,"MGL","O1","C1","C2","C3")
        g.dihedral['C1-C2-C3-O3']=dihedral(mol,"MGL","C1","C2","C3","O3")
        g.dihedral['O1-C1-C2-O2']=dihedral(mol,"MGL","O1","C1","C2","O2")

# %%
class SucroseTopology:
    def __init__(s,mol):
        s.calcIC(mol)
        
        s.hlist=mol.pdb.topology.select("not type H")
        
        s.o1inx={}
        s.c1inx={}
        s.c2inx={}
        s.c3inx={}
        s.c4inx={}
        
        s.excllist={}
        
        s.o1inx['f1']=mol.pdb.topology.select("resname BFRU and name O1")
        s.c1inx['f1']=mol.pdb.topology.select("resname BFRU and name C1")
        s.c2inx['f1']=mol.pdb.topology.select("resname BFRU and name C2")
        s.c3inx['f1']=mol.pdb.topology.select("resname BFRU and name C3")
        s.c4inx['f1']=mol.pdb.topology.select("resname BFRU and name C4")

        s.excllist['f1']=mol.pdb.topology.select(\
                f"not index {s.o1inx['f1'][0]} and not index {s.c1inx['f1'][0]} and \
                  not index {s.c2inx['f1'][0]} and not type H")
        
        s.o1inx['f6']=mol.pdb.topology.select("resname BFRU and name O6")
        s.c1inx['f6']=mol.pdb.topology.select("resname BFRU and name C6")
        s.c2inx['f6']=mol.pdb.topology.select("resname BFRU and name C5")
        s.c3inx['f6']=mol.pdb.topology.select("resname BFRU and name C4")
        s.c4inx['f6']=mol.pdb.topology.select("resname BFRU and name C3")

        s.excllist['f6']=mol.pdb.topology.select(\
                f"not index {s.o1inx['f6'][0]} and not index {s.c1inx['f6'][0]} and \
                  not index {s.c2inx['f6'][0]} and not type H")
        
        s.o1inx['g2']=mol.pdb.topology.select("resname AGLC and name O2")
        s.c1inx['g2']=mol.pdb.topology.select("resname AGLC and name C2")
        s.c2inx['g2']=mol.pdb.topology.select("resname AGLC and name C3")
        s.c3inx['g2']=mol.pdb.topology.select("resname AGLC and name C4")
        s.c4inx['g2']=mol.pdb.topology.select("resname AGLC and name C5")
        
        s.excllist['g2']=mol.pdb.topology.select(\
                f"not index {s.o1inx['g2'][0]} and not index {s.c1inx['g2'][0]} and \
                  not index {s.c2inx['g2'][0]} and not type H")

        s.o1inx['g6']=mol.pdb.topology.select("resname AGLC and name O6")
        s.c1inx['g6']=mol.pdb.topology.select("resname AGLC and name C6")
        s.c2inx['g6']=mol.pdb.topology.select("resname AGLC and name C5")
        s.c3inx['g6']=mol.pdb.topology.select("resname AGLC and name C4")
        s.c4inx['g6']=mol.pdb.topology.select("resname AGLC and name C3")
        
        s.excllist['g6']=mol.pdb.topology.select(\
                f"not index {s.o1inx['g6'][0]} and not index {s.c1inx['g6'][0]} and \
                  not index {s.c2inx['g6'][0]} and not type H")

        s.o1inx['g3']=mol.pdb.topology.select("resname AGLC and name O3")
        s.c1inx['g3']=mol.pdb.topology.select("resname AGLC and name C3")
        s.c2inx['g3']=mol.pdb.topology.select("resname AGLC and name C4")
        s.c3inx['g3']=mol.pdb.topology.select("resname AGLC and name C5")
        s.c4inx['g3']=mol.pdb.topology.select("resname AGLC and name C6")

        s.excllist['g3']=mol.pdb.topology.select(\
                f"not index {s.o1inx['g3'][0]} and not index {s.c1inx['g3'][0]} and \
                  not index {s.c2inx['g3'][0]} and not type H")
        
    def calcIC(s,mol):
        s.bond={}
        s.bond['f1']={}
        s.bond['f1']['O1-C1']=bond(mol,"BFRU","O1","C1")
        s.bond['f1']['C1-C2']=bond(mol,"BFRU","C1","C2")
        s.bond['f1']['C2-C3']=bond(mol,"BFRU","C2","C3")
        s.bond['f1']['C3-C4']=bond(mol,"BFRU","C3","C4")

        s.bond['f6']={}
        s.bond['f6']['O1-C1']=bond(mol,"BFRU","O6","C6")
        s.bond['f6']['C1-C2']=bond(mol,"BFRU","C6","C5")
        s.bond['f6']['C2-C3']=bond(mol,"BFRU","C5","C4")
        s.bond['f6']['C3-C4']=bond(mol,"BFRU","C4","C3")

        s.bond['g2']={}
        s.bond['g2']['O1-C1']=bond(mol,"AGLC","O2","C2")
        s.bond['g2']['C1-C2']=bond(mol,"AGLC","C2","C3")
        s.bond['g2']['C2-C3']=bond(mol,"AGLC","C3","C4")
        s.bond['g2']['C3-C4']=bond(mol,"AGLC","C4","C5")

        s.bond['g6']={}
        s.bond['g6']['O1-C1']=bond(mol,"AGLC","O6","C6")
        s.bond['g6']['C1-C2']=bond(mol,"AGLC","C6","C5")
        s.bond['g6']['C2-C3']=bond(mol,"AGLC","C5","C4")
        s.bond['g6']['C3-C4']=bond(mol,"AGLC","C4","C3")

        s.bond['g3']={}
        s.bond['g3']['O1-C1']=bond(mol,"AGLC","O3","C3")
        s.bond['g3']['C1-C2']=bond(mol,"AGLC","C3","C4")
        s.bond['g3']['C2-C3']=bond(mol,"AGLC","C4","C5")
        s.bond['g3']['C3-C4']=bond(mol,"AGLC","C5","C6")

        s.angle={}
        s.angle['f1']={}
        s.angle['f1']['O1-C1-C2']=angle(mol,"BFRU","O1","C1","C2")
        s.angle['f1']['C1-C2-C3']=angle(mol,"BFRU","C1","C2","C3")
        s.angle['f1']['C2-C3-C4']=angle(mol,"BFRU","C2","C3","C4")

        s.angle['f6']={}
        s.angle['f6']['O1-C1-C2']=angle(mol,"BFRU","O6","C6","C5")
        s.angle['f6']['C1-C2-C3']=angle(mol,"BFRU","C6","C5","C4")
        s.angle['f6']['C2-C3-C4']=angle(mol,"BFRU","C5","C4","C3")
    
        s.angle['g2']={}
        s.angle['g2']['O1-C1-C2']=angle(mol,"AGLC","O2","C2","C3")
        s.angle['g2']['C1-C2-C3']=angle(mol,"AGLC","C2","C3","C4")
        s.angle['g2']['C2-C3-C4']=angle(mol,"AGLC","C3","C4","C5")

        s.angle['g6']={}
        s.angle['g6']['O1-C1-C2']=angle(mol,"AGLC","O6","C6","C5")
        s.angle['g6']['C1-C2-C3']=angle(mol,"AGLC","C6","C5","C4")
        s.angle['g6']['C2-C3-C4']=angle(mol,"AGLC","C5","C4","C3")

        s.angle['g3']={}
        s.angle['g3']['O1-C1-C2']=angle(mol,"AGLC","O3","C3","C4")
        s.angle['g3']['C1-C2-C3']=angle(mol,"AGLC","C3","C4","C5")
        s.angle['g3']['C2-C3-C4']=angle(mol,"AGLC","C4","C5","C6")
                
        s.dihedral={}
        s.dihedral['f1']={}
        s.dihedral['f1']['O1-C1-C2-C3']=dihedral(mol,"BFRU","O1","C1","C2","C3")
        s.dihedral['f1']['C1-C2-C3-C4']=dihedral(mol,"BFRU","C1","C2","C3","C4")

        s.dihedral['f6']={}
        s.dihedral['f6']['O1-C1-C2-C3']=dihedral(mol,"BFRU","O6","C6","C5","C4")
        s.dihedral['f6']['C1-C2-C3-C4']=dihedral(mol,"BFRU","C6","C5","C4","C3")

        s.dihedral['g2']={}
        s.dihedral['g2']['O1-C1-C2-C3']=dihedral(mol,"AGLC","O2","C2","C3","C4")
        s.dihedral['g2']['C1-C2-C3-C4']=dihedral(mol,"AGLC","C2","C3","C4","C5")

        s.dihedral['g6']={}
        s.dihedral['g6']['O1-C1-C2-C3']=dihedral(mol,"AGLC","O6","C6","C5","C4")
        s.dihedral['g6']['C1-C2-C3-C4']=dihedral(mol,"AGLC","C6","C5","C4","C3")

        s.dihedral['g3']={}
        s.dihedral['g3']['O1-C1-C2-C3']=dihedral(mol,"AGLC","O3","C3","C4","C5")
        s.dihedral['g3']['C1-C2-C3-C4']=dihedral(mol,"AGLC","C3","C4","C5","C6")

# %%
gtop=[]
for i in range(len(gmol)):
    gtop+=[GlycerolTopology(gmol[i])]

stop=[]
for i in range(len(smol)):
    stop+=[SucroseTopology(smol[i])]

# %%
class GlycerolUnit:
    def __init__(g,inx,mol,top):
        g.index=inx
        g.resid=inx
        g.mol=copy.deepcopy(mol)
        g.top=top
        g.mapsite={'C1':'MGL:C1', 'O1':'MGL:O1', 'C3':'MGL:C3', 'O3':'MGL:O3'}
        g.connect={}
        g.connectsite={}

    def connectTo(g,site,sucrose,ssite):
        g.connect[site]=sucrose
        g.connectsite[site]=ssite
        
    def nconnect(g):
        return(len(g.connect.values()))
    
    def getatom(g,site,atom):
        return g.mol.getatom(g.mapsite[f'{atom}{site}'])

# %%
class SucroseUnit:
    def __init__(s,inx,mol,top):
        s.index=inx
        s.resid=inx
        s.mol=copy.deepcopy(mol)
        s.mapsite={'Cf1':'BFRU:C1', 'Of1':'BFRU:O1',\
                   'Cf6':'BFRU:C6', 'Of6':'BFRU:O6',\
                   'Cg2':'AGLC:C2', 'Og2':'AGLC:O2',\
                   'Cg6':'AGLC:C6', 'Og6':'AGLC:O6',\
                   'Cg3':'AGLC:C3', 'Og3':'AGLC:O3'}
        
        s.connect={}
        s.connectsite={}
        s.top=top
    
    def connectTo(s,site,glycerol,gsite):
        s.connect[site]=glycerol
        s.connectsite[site]=gsite
        
    def nconnect(s):
        return(len(s.connect.values()))
    
    def nlink(s):
        n=0
        for g in s.connect.values():
            if g.nconnect()>1: n+=1
        return n
    
    def nlone(s):
        return s.nconnect()-s.nlink()

    def getatom(s,site,atom):
        return s.mol.getatom(s.mapsite[f'{atom}{site}'])

# %%
class Ficoll:
    mw={}
    mw['sucrose'] = 342.301
    mw['glycerol'] = 92.0952
    mw['linkdel'] = (15.9994+1.008+1.008)
    
    seg='PROF'
    
    def __init__(f):
        f.sucrose=[]
        f.glycerol=[]
    
    def closest(f,m,list):        
        mind=999999.0
        
        for s in f.sucrose:
            d=minDist(s,m,s.top.hlist,list)
            if (d<mind):
                mind=d
        for g in f.glycerol:
            d=minDist(g,m,g.top.hlist,list)
            if (d<mind):
                mind=d
        return mind
    
    def alignSucroseToGlycerol(f,suc,ssite,igly,gsite):
        cg=f.glycerol[igly].getatom(gsite,'C')
        og=f.glycerol[igly].getatom(gsite,'O')
        
        
        spdb=suc.mol.pdb
        tpdb=copy.deepcopy(spdb)
        
        os=og
        tpdb.xyz[0][suc.top.o1inx[ssite]]=[os]      
        
        cs=buildFromIC(f.glycerol[igly].mol.center(),cg,os,0.143,112.0,160.0)
        tpdb.xyz[0][suc.top.c1inx[ssite]]=[cs]    
        
        fitinx=[suc.top.o1inx[ssite][0], suc.top.c1inx[ssite][0], suc.top.c2inx[ssite][0], \
                suc.top.c3inx[ssite][0], suc.top.c4inx[ssite][0]]
        
        done=False
        ncnt=1
        while not done and ncnt<10:
            rtor=random.random()*360.0-180.0
            c2s=buildFromIC(cg,os,cs,suc.top.bond[ssite]['C1-C2'],suc.top.angle[ssite]['O1-C1-C2'],rtor)
            tpdb.xyz[0][suc.top.c2inx[ssite]]=[c2s]      
            c3s=buildFromIC(os,cs,c2s,suc.top.bond[ssite]['C2-C3'],suc.top.angle[ssite]['C1-C2-C3'],suc.top.dihedral[ssite]['O1-C1-C2-C3'])
            tpdb.xyz[0][suc.top.c3inx[ssite]]=[c3s]
            c4s=buildFromIC(cs,c2s,c3s,suc.top.bond[ssite]['C3-C4'],suc.top.angle[ssite]['C2-C3-C4'],suc.top.dihedral[ssite]['C1-C2-C3-C4'])
            tpdb.xyz[0][suc.top.c4inx[ssite]]=[c4s]
            
            spdb.superpose(tpdb,atom_indices=fitinx)
            d=f.closest(suc,suc.top.excllist[ssite])
            if (d>0.2):
                done=True
            else:
                ncnt+=1
                
        return done
        
    def alignGlycerolToSucrose(f,glyc,isuc,ssite):
        gpdb=glyc.mol.pdb
        tpdb=copy.deepcopy(gpdb)

        csuc=f.sucrose[isuc].getatom(ssite,'C')
        osuc=f.sucrose[isuc].getatom(ssite,'O')
        
        og=osuc
        tpdb.xyz[0][glyc.top.o1inx]=[og]
        
        cg=buildFromIC(f.sucrose[isuc].mol.center(),csuc,og,0.143,112.0,160.0)
        tpdb.xyz[0][glyc.top.c1inx]=[cg]    

        fitinx=[glyc.top.o1inx[0], glyc.top.c1inx[0], glyc.top.c2inx[0], glyc.top.c3inx[0], glyc.top.o2inx[0], glyc.top.o3inx[0]]
                       
        done=False
        ncnt=1
        while not done and ncnt<10:
            rtor=random.random()*360.0-180.0
            c2g=buildFromIC(csuc,og,cg,glyc.top.bond['C1-C2'],glyc.top.angle['O1-C1-C2'],rtor)
            tpdb.xyz[0][glyc.top.c2inx]=[c2g]   
            c3g=buildFromIC(og,cg,c2g,glyc.top.bond['C2-C3'],glyc.top.angle['C1-C2-C3'],glyc.top.dihedral['O1-C1-C2-C3'])
            tpdb.xyz[0][glyc.top.c3inx]=[c3g]
            o3g=buildFromIC(cg,c2g,c3g,glyc.top.bond['C3-O3'],glyc.top.angle['C2-C3-O3'],glyc.top.dihedral['C1-C2-C3-O3'])
            tpdb.xyz[0][glyc.top.o3inx]=[o3g]
            o2g=buildFromIC(og,cg,c2g,glyc.top.bond['C2-O2'],glyc.top.angle['C1-C2-O2'],glyc.top.dihedral['O1-C1-C2-O2'])
            tpdb.xyz[0][glyc.top.o2inx]=[o2g]
            
            gpdb.superpose(tpdb,atom_indices=fitinx)
            d=f.closest(glyc,glyc.top.excllist)
            if (d>0.2):
                done=True
            else:
                ncnt+=1
                
        return done
         
    def addSucrose(f,mol,top,minx,igly=-1,site=''):
        isuc=len(f.sucrose)
        s=SucroseUnit(isuc+1,mol[minx],top[minx])
        
        add=False
        if (igly>=0):
            ok=f.alignSucroseToGlycerol(s,site,igly,'3')
            if (ok):
                f.glycerol[igly].connectTo('3',s,site)
                s.connectTo(site,f.glycerol[igly],'3')
                add=True
        else:
            add=True
            
        if (add):
            f.sucrose+=[s]    
            return isuc
        else:
            return -1
    
    def addGlycerol(f,mol,top,minx,isuc=-1,site=''):
        igly=len(f.glycerol)
        g=GlycerolUnit(igly+1,mol[minx],top[minx])
        
        add=False
        if (isuc>=0):
            ok=f.alignGlycerolToSucrose(g,isuc,site)
            if (ok):
                f.sucrose[isuc].connectTo(site,g,'1')
                g.connectTo('1',f.sucrose[isuc],site)
                add=True
        else: 
            add=True
            
        if (add):
            f.glycerol+=[g]
            return igly
        else:            
            return -1
        
    def molecularweight(f):
        totmw=len(f.sucrose)*f.mw['sucrose']+len(f.glycerol)*f.mw['glycerol']
        for g in f.glycerol:
            totmw-=f.mw['linkdel']*g.nconnect()
        return totmw
    
    def nglycerol(f):
        return len(f.glycerol)

    def nsucrose(f):
        return len(f.sucrose)
    
    def glycerolPerSucrose(f):
        return f.nglycerol()/f.nsucrose()

    def glycerolLinkFraction(f):
        sum=0.0
        for g in f.glycerol:
            sum+=(g.nconnect()-1)
        return sum/f.nglycerol()
    
    def generate(f):
        ires=1
        for s in f.sucrose:
            s.resid=ires
            ires+=2
        for g in f.glycerol:
            g.resid=ires
            ires+=1
        
    def write(f,fname):
        f.generate()
        
        if fname:
            fout=open(fname,"w")
        else:
            fout=stdout
            
        iatom=1
        for s in f.sucrose:
            p=s.mol.pdb
            t=p.topology
            for a in t.residue(0).atoms:
                if ('f1' in s.connect and (a.name == 'HO1')): 
                    continue
                elif ('f6' in s.connect and (a.name == 'HO6')):
                    continue
                printPDB(fout,a,iatom,s.resid,p.xyz[0][a.index],f.seg)
                iatom+=1
            
            for a in t.residue(1).atoms:
                if ('g2' in s.connect and (a.name == 'HO2')): 
                    continue
                elif ('g3' in s.connect and (a.name == 'HO3')):
                    continue
                elif ('g6' in s.connect and (a.name == 'HO6')):
                    continue
                printPDB(fout,a,iatom,s.resid+1,p.xyz[0][a.index],f.seg)
                iatom+=1
            
        for g in f.glycerol:
            p=g.mol.pdb
            t=p.topology
            for a in t.atoms:
                if ('1' in g.connect and (a.name == 'O1' or a.name == 'HO1')): 
                    continue
                elif ('3' in g.connect and (a.name == 'O3' or a.name == 'HO3')):
                    continue
            
                printPDB(fout,a,iatom,g.resid,p.xyz[0][a.index],f.seg)                    
                iatom+=1
        
        fout.write("TER\n")
        fout.write("END\n")
        fout.close()
        
    def patches(f,fname):
        f.generate()
        
        if fname:
            fout=open(fname,"w")
        else:
            fout=stdout
        
        for s in f.sucrose:
            print("SUCR:%s.%d:%s.%d" % (f.seg,s.resid+1,f.seg,s.resid))
            if 'f1' in s.connect:
                fout.write("FG1%s:%s.%d:%s.%d" % (s.connectsite['f1'],f.seg,s.resid,f.seg,s.connect['f1'].resid))
            if 'f6' in s.connect:
                fout.write("FG6%s:%s.%d:%s.%d" % (s.connectsite['f6'],f.seg,s.resid,f.seg,s.connect['f6'].resid))
            if 'g2' in s.connect:
                fout.write("GG2%s:%s.%d:%s.%d" % (s.connectsite['g2'],f.seg,s.resid+1,f.seg,s.connect['g2'].resid))
            if 'g3' in s.connect:
                fout.write("GG3%s:%s.%d:%s.%d" % (s.connectsite['g3'],f.seg,s.resid+1,f.seg,s.connect['g3'].resid))
            if 'g6' in s.connect:
                fout.write("GG6%s:%s.%d:%s.%d" % (s.connectsite['g6'],f.seg,s.resid+1,f.seg,s.connect['g6'].resid))

# %%
def buildFromIC(a,b,c,r,theta,phi):   
    sinTheta=math.sin(theta*math.pi/180.0)
    cosTheta=math.cos(theta*math.pi/180.0)
    sinPhi=math.sin(phi*math.pi/180.0)
    cosPhi=math.cos(phi*math.pi/180.0)

    x=r*cosTheta
    y=r*cosPhi*sinTheta
    z=r*sinPhi*sinTheta
    
    a=np.array(a)
    b=np.array(b)
    c=np.array(c)
    
    ab=b-a
    bc=c-b
    bc=bc/np.linalg.norm(bc)
    
    n=np.cross(ab,bc)
    n=n/np.linalg.norm(n)
    ncbc=np.cross(n,bc)
    
    m=np.array([[bc[0],ncbc[0],n[0]], [bc[1],ncbc[1],n[1]], [bc[2],ncbc[2],n[2]]])
    d=np.matmul(m,np.array([-x,y,z]))+c
    return(d.tolist())
    
def minDist(m1,m2,hlist,list):
    mind=999999.0
    for h in hlist:
        xyz1=m1.mol.pdb.xyz[0][h]
        for l in list:
            xyz2=m2.mol.pdb.xyz[0][l]
            dx=xyz2-xyz1
            #numpy.sqrt(numpy.sum((a - b) ** 2, axis=0))
            #d=np.linalg.norm(dx)
            d=np.sum(dx**2)
            if (d<mind):
                mind=d
    return np.sqrt(mind)

def printPDB(fout,a,natom,nres,xyz,seg):
    fout.write("ATOM%7d %-4s %-4s%1s%-6s  %8.3f%8.3f%8.3f %5.2f%6.2f      %-4s\n" % \
              (natom,a.name,a.residue.name," ",nres,xyz[0]*10.0,xyz[1]*10.0,xyz[2]*10.0,1.0,0.0,seg))

# %% [markdown]
# Example for how to assemble a molecule manually:

# %%
f=Ficoll()

is1=f.addSucrose(smol,stop,0)
ig1=f.addGlycerol(gmol,gtop,0,is1,'f6')
ig2=f.addGlycerol(gmol,gtop,1,is1,'f1')
ig3=f.addGlycerol(gmol,gtop,0,is1,'g2')

is2=f.addSucrose(smol,stop,0,ig1,'f1')
is3=f.addSucrose(smol,stop,0,ig2,'g2')
is4=f.addSucrose(smol,stop,0,ig3,'f1')

ig4=f.addGlycerol(gmol,gtop,2,is4,'g2')

print(f.molecularweight())
print(f.glycerolPerSucrose())

f.write('ficoll-example.pdb')
f.patches()
# Out:
# 1611.477
# 1.0
# SUCR:PROF.2:PROF.1
# FG11:PROF.1:PROF.10
# FG61:PROF.1:PROF.9
# GG21:PROF.2:PROF.11
# SUCR:PROF.4:PROF.3
# FG13:PROF.3:PROF.9
# SUCR:PROF.6:PROF.5
# GG23:PROF.6:PROF.10
# SUCR:PROF.8:PROF.7
# FG13:PROF.7:PROF.11
# GG21:PROF.8:PROF.12

# %% [markdown]
# Automatic assembly

# %%
avgGlycerolPerSucrose=2.5
probGlycerolLink=0.6

targetMW = 70000     # in Dalton

prob={}
prob['f1']=0.3
prob['f6']=0.2
prob['g2']=0.25
prob['g6']=0.3
prob['g3']=0.05

def randomSite(p):
    v=random.random()
    sum=0.0
    for s in p:
        sum+=p[s]
        if (v<sum):
            return s
    return ''

# %%
f=Ficoll()

isuc=f.addSucrose(smol,stop,random.randrange(len(smol)))
islist=[isuc]
while(f.molecularweight()<targetMW and len(islist)>0):
    iglist=[]
    random.shuffle(islist)
    for s in islist:
        cnt=0
        while (f.glycerolPerSucrose()<avgGlycerolPerSucrose and cnt<10 and f.molecularweight()<targetMW):
            rsite=randomSite(prob)
                #print(rsite)
            if rsite in f.sucrose[s].connect:
                cnt+=1
                continue
            igly=f.addGlycerol(gmol,gtop,random.randrange(len(gmol)),s,rsite)
            if (igly>=0): iglist+=[igly]
        
    print("added %3d glycerols : mw %10.2lf : %5.2lf glyc/suc : %5.2lf links/glyc" %\
          (len(iglist), f.molecularweight(), f.glycerolPerSucrose(), f.glycerolLinkFraction()))

    islist=[]
    random.shuffle(iglist)
    for g in iglist:
        if (random.random()<probGlycerolLink*1.20 and f.molecularweight()<targetMW):
            rsite=randomSite(prob)
            isuc=f.addSucrose(smol,stop,random.randrange(len(smol)),g,rsite)
            if (isuc>=0): islist+=[isuc]
            
    if (len(islist)==0 and f.molecularweight()<targetMW):
        #print(f'add at least one')
        g=iglist[random.randrange(len(iglist))]
        rsite=randomSite(prob)
        isuc=f.addSucrose(smol[random.randrange(len(smol))],g,rsite)
        if (isuc>=0): islist+=[isuc]

    print("added %3d sucroses  : mw %10.2lf : %5.2lf glyc/suc : %5.2lf links/glyc" %\
          (len(islist), f.molecularweight(), f.glycerolPerSucrose(), f.glycerolLinkFraction()))
# Out:
# added   3 glycerols : mw     564.54 :  3.00 glyc/suc :  0.00 links/glyc
# added   2 sucroses  : mw    1213.11 :  1.00 glyc/suc :  0.67 links/glyc
# added   5 glycerols : mw    1583.51 :  2.67 glyc/suc :  0.25 links/glyc
# added   2 sucroses  : mw    2232.08 :  1.60 glyc/suc :  0.50 links/glyc
# added   5 glycerols : mw    2602.48 :  2.60 glyc/suc :  0.31 links/glyc
# added   4 sucroses  : mw    3899.62 :  1.44 glyc/suc :  0.62 links/glyc
# added  10 glycerols : mw    4640.42 :  2.56 glyc/suc :  0.35 links/glyc
# added   6 sucroses  : mw    6586.13 :  1.53 glyc/suc :  0.61 links/glyc
# added  15 glycerols : mw    7697.33 :  2.53 glyc/suc :  0.37 links/glyc
# added   8 sucroses  : mw   10291.62 :  1.65 glyc/suc :  0.58 links/glyc
# added  20 glycerols : mw   11773.21 :  2.52 glyc/suc :  0.38 links/glyc
# added  13 sucroses  : mw   15988.93 :  1.61 glyc/suc :  0.60 links/glyc
# added  32 glycerols : mw   18359.48 :  2.50 glyc/suc :  0.39 links/glyc
# added  19 sucroses  : mw   24520.91 :  1.64 glyc/suc :  0.60 links/glyc
# added  48 glycerols : mw   28076.74 :  2.51 glyc/suc :  0.39 links/glyc
# added  32 sucroses  : mw   38453.88 :  1.59 glyc/suc :  0.62 links/glyc
# added  80 glycerols : mw   44380.26 :  2.51 glyc/suc :  0.39 links/glyc
# added  48 sucroses  : mw   59945.97 :  1.61 glyc/suc :  0.61 links/glyc
# added 120 glycerols : mw   68835.54 :  2.50 glyc/suc :  0.40 links/glyc
# added   4 sucroses  : mw   70132.69 :  2.43 glyc/suc :  0.41 links/glyc

# %% [markdown]
# Saving molecule

# %%
f.write('ficoll.pdb')

# %% [markdown]
# Writing out patches

# %%
f.patches()
# Out:
# SUCR:PROF.2:PROF.1
# FG11:PROF.1:PROF.281
# FG61:PROF.1:PROF.279
# GG21:PROF.2:PROF.280
# SUCR:PROF.4:PROF.3
# FG11:PROF.3:PROF.284
# FG61:PROF.3:PROF.283
# GG21:PROF.4:PROF.282
# GG63:PROF.4:PROF.281
# SUCR:PROF.6:PROF.5
# FG11:PROF.5:PROF.286
# FG61:PROF.5:PROF.285
# GG63:PROF.6:PROF.280
# SUCR:PROF.8:PROF.7
# FG13:PROF.7:PROF.283
# GG21:PROF.8:PROF.291
# GG61:PROF.8:PROF.290
# SUCR:PROF.10:PROF.9
# FG11:PROF.9:PROF.289
# FG63:PROF.9:PROF.285
# GG21:PROF.10:PROF.288
# GG61:PROF.10:PROF.287
# SUCR:PROF.12:PROF.11
# FG13:PROF.11:PROF.290
# FG61:PROF.11:PROF.294
# GG21:PROF.12:PROF.292
# GG61:PROF.12:PROF.293
# SUCR:PROF.14:PROF.13
# FG13:PROF.13:PROF.291
# FG61:PROF.13:PROF.297
# GG21:PROF.14:PROF.296
# GG61:PROF.14:PROF.295
# SUCR:PROF.16:PROF.15
# FG11:PROF.15:PROF.299
# FG61:PROF.15:PROF.298
# GG21:PROF.16:PROF.300
# GG63:PROF.16:PROF.287
# SUCR:PROF.18:PROF.17
# FG63:PROF.17:PROF.289
# GG61:PROF.18:PROF.301
# SUCR:PROF.20:PROF.19
# FG11:PROF.19:PROF.315
# FG63:PROF.19:PROF.293
# GG21:PROF.20:PROF.313
# GG61:PROF.20:PROF.314
# SUCR:PROF.22:PROF.21
# FG11:PROF.21:PROF.310
# FG61:PROF.21:PROF.308
# GG23:PROF.22:PROF.292
# GG61:PROF.22:PROF.309
# SUCR:PROF.24:PROF.23
# FG11:PROF.23:PROF.307
# FG63:PROF.23:PROF.294
# GG21:PROF.24:PROF.305
# GG61:PROF.24:PROF.306
# SUCR:PROF.26:PROF.25
# FG11:PROF.25:PROF.312
# GG21:PROF.26:PROF.311
# GG63:PROF.26:PROF.298
# SUCR:PROF.28:PROF.27
# FG63:PROF.27:PROF.301
# GG61:PROF.28:PROF.316
# SUCR:PROF.30:PROF.29
# FG11:PROF.29:PROF.302
# FG63:PROF.29:PROF.295
# GG21:PROF.30:PROF.304
# GG61:PROF.30:PROF.303
# SUCR:PROF.32:PROF.31
# FG13:PROF.31:PROF.312
# FG61:PROF.31:PROF.331
# GG21:PROF.32:PROF.332
# GG61:PROF.32:PROF.330
# SUCR:PROF.34:PROF.33
# FG11:PROF.33:PROF.325
# FG61:PROF.33:PROF.326
# GG21:PROF.34:PROF.327
# GG63:PROF.34:PROF.313
# SUCR:PROF.36:PROF.35
# FG13:PROF.35:PROF.307
# GG21:PROF.36:PROF.323
# GG61:PROF.36:PROF.324
# SUCR:PROF.38:PROF.37
# FG13:PROF.37:PROF.305
# GG21:PROF.38:PROF.329
# GG61:PROF.38:PROF.328
# SUCR:PROF.40:PROF.39
# FG11:PROF.39:PROF.317
# FG61:PROF.39:PROF.319
# GG21:PROF.40:PROF.318
# GG63:PROF.40:PROF.308
# SUCR:PROF.42:PROF.41
# FG11:PROF.41:PROF.320
# FG61:PROF.41:PROF.321
# GG21:PROF.42:PROF.322
# GG63:PROF.42:PROF.311
# SUCR:PROF.44:PROF.43
# FG11:PROF.43:PROF.335
# FG63:PROF.43:PROF.304
# GG61:PROF.44:PROF.336
# SUCR:PROF.46:PROF.45
# FG11:PROF.45:PROF.334
# GG21:PROF.46:PROF.333
# GG63:PROF.46:PROF.315
# SUCR:PROF.48:PROF.47
# FG11:PROF.47:PROF.337
# FG63:PROF.47:PROF.331
# GG21:PROF.48:PROF.339
# GG61:PROF.48:PROF.338
# SUCR:PROF.50:PROF.49
# FG13:PROF.49:PROF.319
# FG61:PROF.49:PROF.368
# GG21:PROF.50:PROF.366
# GG61:PROF.50:PROF.367
# SUCR:PROF.52:PROF.51
# FG11:PROF.51:PROF.359
# FG63:PROF.51:PROF.332
# GG21:PROF.52:PROF.358
# GG61:PROF.52:PROF.357
# SUCR:PROF.54:PROF.53
# FG11:PROF.53:PROF.346
# FG61:PROF.53:PROF.347
# GG21:PROF.54:PROF.348
# GG63:PROF.54:PROF.323
# SUCR:PROF.56:PROF.55
# GG23:PROF.56:PROF.334
# SUCR:PROF.58:PROF.57
# FG11:PROF.57:PROF.349
# FG61:PROF.57:PROF.350
# GG23:PROF.58:PROF.335
# GG61:PROF.58:PROF.351
# SUCR:PROF.60:PROF.59
# FG11:PROF.59:PROF.342
# FG61:PROF.59:PROF.341
# GG21:PROF.60:PROF.340
# GG63:PROF.60:PROF.330
# SUCR:PROF.62:PROF.61
# GG23:PROF.62:PROF.333
# SUCR:PROF.64:PROF.63
# FG13:PROF.63:PROF.318
# FG61:PROF.63:PROF.344
# GG21:PROF.64:PROF.343
# GG61:PROF.64:PROF.345
# SUCR:PROF.66:PROF.65
# FG11:PROF.65:PROF.352
# FG61:PROF.65:PROF.353
# GG23:PROF.66:PROF.325
# GG61:PROF.66:PROF.354
# SUCR:PROF.68:PROF.67
# FG11:PROF.67:PROF.363
# FG61:PROF.67:PROF.364
# GG21:PROF.68:PROF.365
# GG63:PROF.68:PROF.322
# SUCR:PROF.70:PROF.69
# FG11:PROF.69:PROF.361
# FG61:PROF.69:PROF.360
# GG23:PROF.70:PROF.326
# GG61:PROF.70:PROF.362
# SUCR:PROF.72:PROF.71
# FG11:PROF.71:PROF.355
# GG21:PROF.72:PROF.356
# GG63:PROF.72:PROF.324
# SUCR:PROF.74:PROF.73
# FG11:PROF.73:PROF.391
# FG63:PROF.73:PROF.363
# GG21:PROF.74:PROF.390
# GG61:PROF.74:PROF.392
# SUCR:PROF.76:PROF.75
# FG11:PROF.75:PROF.414
# FG61:PROF.75:PROF.412
# GG21:PROF.76:PROF.413
# GG63:PROF.76:PROF.355
# SUCR:PROF.78:PROF.77
# FG11:PROF.77:PROF.389
# FG61:PROF.77:PROF.387
# GG21:PROF.78:PROF.388
# GG63:PROF.78:PROF.348
# SUCR:PROF.80:PROF.79
# FG11:PROF.79:PROF.372
# FG61:PROF.79:PROF.373
# GG23:PROF.80:PROF.354
# SUCR:PROF.82:PROF.81
# FG61:PROF.81:PROF.383
# GG23:PROF.82:PROF.353
# GG61:PROF.82:PROF.384
# SUCR:PROF.84:PROF.83
# FG11:PROF.83:PROF.386
# FG63:PROF.83:PROF.365
# GG61:PROF.84:PROF.385
# SUCR:PROF.86:PROF.85
# FG11:PROF.85:PROF.393
# FG61:PROF.85:PROF.394
# GG21:PROF.86:PROF.395
# GG63:PROF.86:PROF.338
# SUCR:PROF.88:PROF.87
# GG63:PROF.88:PROF.339
# SUCR:PROF.90:PROF.89
# FG11:PROF.89:PROF.402
# FG61:PROF.89:PROF.404
# GG21:PROF.90:PROF.403
# GG63:PROF.90:PROF.340
# SUCR:PROF.92:PROF.91
# FG11:PROF.91:PROF.406
# GG23:PROF.92:PROF.367
# GG61:PROF.92:PROF.405
# SUCR:PROF.94:PROF.93
# FG11:PROF.93:PROF.381
# FG61:PROF.93:PROF.380
# GG21:PROF.94:PROF.382
# GG63:PROF.94:PROF.364
# SUCR:PROF.96:PROF.95
# FG11:PROF.95:PROF.415
# GG21:PROF.96:PROF.416
# GG63:PROF.96:PROF.346
# SUCR:PROF.98:PROF.97
# FG11:PROF.97:PROF.371
# FG61:PROF.97:PROF.369
# GG23:PROF.98:PROF.361
# GG61:PROF.98:PROF.370
# SUCR:PROF.100:PROF.99
# FG11:PROF.99:PROF.377
# FG61:PROF.99:PROF.379
# GG21:PROF.100:PROF.378
# GG63:PROF.100:PROF.358
# SUCR:PROF.102:PROF.101
# FG11:PROF.101:PROF.407
# FG61:PROF.101:PROF.409
# GG21:PROF.102:PROF.408
# GG63:PROF.102:PROF.345
# SUCR:PROF.104:PROF.103
# FG11:PROF.103:PROF.411
# GG21:PROF.104:PROF.410
# GG63:PROF.104:PROF.352
# SUCR:PROF.106:PROF.105
# FG11:PROF.105:PROF.374
# FG61:PROF.105:PROF.376
# GG21:PROF.106:PROF.375
# GG63:PROF.106:PROF.351
# SUCR:PROF.108:PROF.107
# FG13:PROF.107:PROF.356
# FG61:PROF.107:PROF.399
# GG21:PROF.108:PROF.401
# GG61:PROF.108:PROF.400
# SUCR:PROF.110:PROF.109
# FG11:PROF.109:PROF.396
# FG61:PROF.109:PROF.398
# GG21:PROF.110:PROF.397
# GG63:PROF.110:PROF.344
# SUCR:PROF.112:PROF.111
# FG11:PROF.111:PROF.468
# FG61:PROF.111:PROF.467
# GG23:PROF.112:PROF.415
# GG61:PROF.112:PROF.469
# SUCR:PROF.114:PROF.113
# FG11:PROF.113:PROF.463
# FG63:PROF.113:PROF.393
# GG21:PROF.114:PROF.461
# GG61:PROF.114:PROF.462
# SUCR:PROF.116:PROF.115
# FG61:PROF.115:PROF.426
# GG23:PROF.116:PROF.396
# GG61:PROF.116:PROF.427
# SUCR:PROF.118:PROF.117
# FG13:PROF.117:PROF.375
# FG61:PROF.117:PROF.422
# GG21:PROF.118:PROF.420
# GG61:PROF.118:PROF.421
# SUCR:PROF.120:PROF.119
# FG11:PROF.119:PROF.491
# FG61:PROF.119:PROF.493
# GG23:PROF.120:PROF.369
# GG61:PROF.120:PROF.492
# SUCR:PROF.122:PROF.121
# FG11:PROF.121:PROF.464
# FG61:PROF.121:PROF.466
# GG23:PROF.122:PROF.399
# GG61:PROF.122:PROF.465
# SUCR:PROF.124:PROF.123
# FG61:PROF.123:PROF.485
# GG23:PROF.124:PROF.416
# GG61:PROF.124:PROF.484
# SUCR:PROF.126:PROF.125
# FG11:PROF.125:PROF.417
# FG61:PROF.125:PROF.419
# GG23:PROF.126:PROF.412
# GG61:PROF.126:PROF.418
# SUCR:PROF.128:PROF.127
# FG61:PROF.127:PROF.442
# GG23:PROF.128:PROF.374
# GG61:PROF.128:PROF.441
# SUCR:PROF.130:PROF.129
# FG11:PROF.129:PROF.423
# FG63:PROF.129:PROF.384
# GG21:PROF.130:PROF.425
# GG61:PROF.130:PROF.424
# SUCR:PROF.132:PROF.131
# FG13:PROF.131:PROF.390
# FG61:PROF.131:PROF.447
# GG21:PROF.132:PROF.446
# GG61:PROF.132:PROF.448
# SUCR:PROF.134:PROF.133
# FG13:PROF.133:PROF.409
# FG61:PROF.133:PROF.488
# GG21:PROF.134:PROF.489
# GG61:PROF.134:PROF.490
# SUCR:PROF.136:PROF.135
# GG63:PROF.136:PROF.395
# SUCR:PROF.138:PROF.137
# FG11:PROF.137:PROF.473
# FG61:PROF.137:PROF.472
# GG23:PROF.138:PROF.378
# GG61:PROF.138:PROF.474
# SUCR:PROF.140:PROF.139
# FG61:PROF.139:PROF.455
# GG23:PROF.140:PROF.389
# GG61:PROF.140:PROF.454
# SUCR:PROF.142:PROF.141
# FG11:PROF.141:PROF.429
# FG61:PROF.141:PROF.430
# GG23:PROF.142:PROF.391
# GG61:PROF.142:PROF.428
# SUCR:PROF.144:PROF.143
# FG11:PROF.143:PROF.435
# FG63:PROF.143:PROF.404
# GG21:PROF.144:PROF.436
# GG61:PROF.144:PROF.434
# SUCR:PROF.146:PROF.145
# FG11:PROF.145:PROF.450
# FG63:PROF.145:PROF.410
# GG21:PROF.146:PROF.449
# SUCR:PROF.148:PROF.147
# FG13:PROF.147:PROF.406
# FG61:PROF.147:PROF.487
# GG21:PROF.148:PROF.486
# SUCR:PROF.150:PROF.149
# FG13:PROF.149:PROF.414
# GG21:PROF.150:PROF.439
# GG61:PROF.150:PROF.440
# SUCR:PROF.152:PROF.151
# FG11:PROF.151:PROF.456
# FG63:PROF.151:PROF.400
# GG21:PROF.152:PROF.457
# SUCR:PROF.154:PROF.153
# FG11:PROF.153:PROF.432
# FG61:PROF.153:PROF.433
# GG23:PROF.154:PROF.386
# GG61:PROF.154:PROF.431
# SUCR:PROF.156:PROF.155
# FG11:PROF.155:PROF.471
# FG63:PROF.155:PROF.372
# GG21:PROF.156:PROF.470
# SUCR:PROF.158:PROF.157
# FG11:PROF.157:PROF.476
# FG61:PROF.157:PROF.475
# GG23:PROF.158:PROF.377
# GG61:PROF.158:PROF.477
# SUCR:PROF.160:PROF.159
# FG61:PROF.159:PROF.438
# GG21:PROF.160:PROF.437
# GG63:PROF.160:PROF.392
# SUCR:PROF.162:PROF.161
# FG13:PROF.161:PROF.381
# FG61:PROF.161:PROF.453
# GG21:PROF.162:PROF.451
# GG61:PROF.162:PROF.452
# SUCR:PROF.164:PROF.163
# FG11:PROF.163:PROF.444
# FG61:PROF.163:PROF.443
# GG23:PROF.164:PROF.373
# GG61:PROF.164:PROF.445
# SUCR:PROF.166:PROF.165
# FG11:PROF.165:PROF.494
# GG21:PROF.166:PROF.495
# GG63:PROF.166:PROF.397
# SUCR:PROF.168:PROF.167
# FG11:PROF.167:PROF.459
# FG61:PROF.167:PROF.460
# GG23:PROF.168:PROF.407
# GG61:PROF.168:PROF.458
# SUCR:PROF.170:PROF.169
# FG13:PROF.169:PROF.405
# GG21:PROF.170:PROF.496
# SUCR:PROF.172:PROF.171
# FG13:PROF.171:PROF.413
# FG61:PROF.171:PROF.483
# GG21:PROF.172:PROF.482
# GG61:PROF.172:PROF.481
# SUCR:PROF.174:PROF.173
# FG11:PROF.173:PROF.478
# FG61:PROF.173:PROF.479
# GG21:PROF.174:PROF.480
# GG63:PROF.174:PROF.411
# SUCR:PROF.176:PROF.175
# FG13:PROF.175:PROF.467
# FG61:PROF.175:PROF.605
# GG21:PROF.176:PROF.604
# GG61:PROF.176:PROF.606
# SUCR:PROF.178:PROF.177
# FG13:PROF.177:PROF.457
# FG61:PROF.177:PROF.585
# GG21:PROF.178:PROF.586
# GG61:PROF.178:PROF.584
# SUCR:PROF.180:PROF.179
# FG13:PROF.179:PROF.461
# SUCR:PROF.182:PROF.181
# FG11:PROF.181:PROF.509
# FG61:PROF.181:PROF.507
# GG21:PROF.182:PROF.508
# GG63:PROF.182:PROF.462
# SUCR:PROF.184:PROF.183
# FG13:PROF.183:PROF.434
# FG61:PROF.183:PROF.570
# GG21:PROF.184:PROF.569
# GG61:PROF.184:PROF.568
# SUCR:PROF.186:PROF.185
# FG11:PROF.185:PROF.538
# GG21:PROF.186:PROF.539
# GG63:PROF.186:PROF.492
# SUCR:PROF.188:PROF.187
# FG11:PROF.187:PROF.593
# FG63:PROF.187:PROF.452
# GG21:PROF.188:PROF.594
# GG61:PROF.188:PROF.595
# SUCR:PROF.190:PROF.189
# FG11:PROF.189:PROF.536
# FG61:PROF.189:PROF.537
# GG23:PROF.190:PROF.481
# SUCR:PROF.192:PROF.191
# FG61:PROF.191:PROF.525
# GG23:PROF.192:PROF.437
# GG61:PROF.192:PROF.524
# SUCR:PROF.194:PROF.193
# FG11:PROF.193:PROF.545
# FG61:PROF.193:PROF.543
# GG21:PROF.194:PROF.544
# GG63:PROF.194:PROF.449
# SUCR:PROF.196:PROF.195
# FG63:PROF.195:PROF.444
# GG61:PROF.196:PROF.506
# SUCR:PROF.198:PROF.197
# FG13:PROF.197:PROF.433
# FG61:PROF.197:PROF.499
# GG21:PROF.198:PROF.498
# GG61:PROF.198:PROF.497
# SUCR:PROF.200:PROF.199
# FG11:PROF.199:PROF.556
# FG63:PROF.199:PROF.469
# GG21:PROF.200:PROF.555
# GG61:PROF.200:PROF.554
# SUCR:PROF.202:PROF.201
# FG13:PROF.201:PROF.421
# GG21:PROF.202:PROF.553
# GG61:PROF.202:PROF.552
# SUCR:PROF.204:PROF.203
# FG13:PROF.203:PROF.441
# FG61:PROF.203:PROF.601
# GG21:PROF.204:PROF.603
# GG61:PROF.204:PROF.602
# SUCR:PROF.206:PROF.205
# FG13:PROF.205:PROF.477
# GG21:PROF.206:PROF.615
# GG61:PROF.206:PROF.616
# SUCR:PROF.208:PROF.207
# FG11:PROF.207:PROF.512
# FG61:PROF.207:PROF.510
# GG21:PROF.208:PROF.511
# GG63:PROF.208:PROF.464
# SUCR:PROF.210:PROF.209
# FG13:PROF.209:PROF.454
# FG61:PROF.209:PROF.551
# GG21:PROF.210:PROF.549
# GG61:PROF.210:PROF.550
# SUCR:PROF.212:PROF.211
# FG11:PROF.211:PROF.523
# FG61:PROF.211:PROF.521
# GG21:PROF.212:PROF.522
# GG63:PROF.212:PROF.474
# SUCR:PROF.214:PROF.213
# FG11:PROF.213:PROF.502
# FG61:PROF.213:PROF.500
# GG21:PROF.214:PROF.501
# GG63:PROF.214:PROF.485
# SUCR:PROF.216:PROF.215
# FG11:PROF.215:PROF.559
# FG61:PROF.215:PROF.560
# GG21:PROF.216:PROF.561
# GG63:PROF.216:PROF.426
# SUCR:PROF.218:PROF.217
# FG11:PROF.217:PROF.562
# FG63:PROF.217:PROF.455
# GG21:PROF.218:PROF.563
# GG61:PROF.218:PROF.564
# SUCR:PROF.220:PROF.219
# FG13:PROF.219:PROF.456
# GG21:PROF.220:PROF.583
# GG61:PROF.220:PROF.582
# SUCR:PROF.222:PROF.221
# FG11:PROF.221:PROF.515
# FG63:PROF.221:PROF.496
# GG21:PROF.222:PROF.516
# GG61:PROF.222:PROF.517
# SUCR:PROF.224:PROF.223
# FG13:PROF.223:PROF.460
# FG61:PROF.223:PROF.578
# GG21:PROF.224:PROF.577
# GG61:PROF.224:PROF.576
# SUCR:PROF.226:PROF.225
# FG11:PROF.225:PROF.598
# FG61:PROF.225:PROF.600
# GG23:PROF.226:PROF.435
# GG61:PROF.226:PROF.599
# SUCR:PROF.228:PROF.227
# FG11:PROF.227:PROF.580
# FG61:PROF.227:PROF.581
# GG21:PROF.228:PROF.579
# GG63:PROF.228:PROF.431
# SUCR:PROF.230:PROF.229
# FG11:PROF.229:PROF.540
# FG61:PROF.229:PROF.542
# GG21:PROF.230:PROF.541
# GG63:PROF.230:PROF.451
# SUCR:PROF.232:PROF.231
# FG13:PROF.231:PROF.424
# FG61:PROF.231:PROF.610
# GG21:PROF.232:PROF.611
# SUCR:PROF.234:PROF.233
# FG13:PROF.233:PROF.427
# FG61:PROF.233:PROF.591
# GG21:PROF.234:PROF.592
# GG61:PROF.234:PROF.590
# SUCR:PROF.236:PROF.235
# FG11:PROF.235:PROF.513
# GG21:PROF.236:PROF.514
# GG63:PROF.236:PROF.453
# SUCR:PROF.238:PROF.237
# FG13:PROF.237:PROF.417
# GG21:PROF.238:PROF.557
# GG61:PROF.238:PROF.558
# SUCR:PROF.240:PROF.239
# FG11:PROF.239:PROF.547
# FG61:PROF.239:PROF.548
# GG21:PROF.240:PROF.546
# GG63:PROF.240:PROF.419
# SUCR:PROF.242:PROF.241
# FG61:PROF.241:PROF.526
# GG23:PROF.242:PROF.465
# GG61:PROF.242:PROF.527
# SUCR:PROF.244:PROF.243
# FG11:PROF.243:PROF.612
# FG61:PROF.243:PROF.613
# GG21:PROF.244:PROF.614
# GG63:PROF.244:PROF.438
# SUCR:PROF.246:PROF.245
# FG13:PROF.245:PROF.483
# FG61:PROF.245:PROF.575
# GG21:PROF.246:PROF.574
# GG61:PROF.246:PROF.573
# SUCR:PROF.248:PROF.247
# FG13:PROF.247:PROF.436
# SUCR:PROF.250:PROF.249
# FG11:PROF.249:PROF.518
# FG63:PROF.249:PROF.484
# GG21:PROF.250:PROF.520
# GG61:PROF.250:PROF.519
# SUCR:PROF.252:PROF.251
# FG11:PROF.251:PROF.533
# FG61:PROF.251:PROF.535
# GG21:PROF.252:PROF.534
# GG63:PROF.252:PROF.495
# SUCR:PROF.254:PROF.253
# FG11:PROF.253:PROF.531
# FG61:PROF.253:PROF.530
# GG23:PROF.254:PROF.471
# GG61:PROF.254:PROF.532
# SUCR:PROF.256:PROF.255
# FG11:PROF.255:PROF.503
# FG63:PROF.255:PROF.443
# GG21:PROF.256:PROF.504
# GG61:PROF.256:PROF.505
# SUCR:PROF.258:PROF.257
# FG63:PROF.257:PROF.458
# GG21:PROF.258:PROF.571
# GG61:PROF.258:PROF.572
# SUCR:PROF.260:PROF.259
# FG13:PROF.259:PROF.423
# FG61:PROF.259:PROF.529
# GG21:PROF.260:PROF.528
# SUCR:PROF.262:PROF.261
# FG13:PROF.261:PROF.442
# GG21:PROF.262:PROF.596
# GG61:PROF.262:PROF.597
# SUCR:PROF.264:PROF.263
# FG11:PROF.263:PROF.587
# FG61:PROF.263:PROF.589
# GG23:PROF.264:PROF.470
# GG61:PROF.264:PROF.588
# SUCR:PROF.266:PROF.265
# FG13:PROF.265:PROF.486
# SUCR:PROF.268:PROF.267
# FG13:PROF.267:PROF.463
# FG61:PROF.267:PROF.609
# GG21:PROF.268:PROF.608
# GG61:PROF.268:PROF.607
# SUCR:PROF.270:PROF.269
# FG13:PROF.269:PROF.448
# FG61:PROF.269:PROF.565
# GG21:PROF.270:PROF.567
# GG61:PROF.270:PROF.566
# SUCR:PROF.272:PROF.271
# FG13:PROF.271:PROF.571
# SUCR:PROF.274:PROF.273
# GG23:PROF.274:PROF.559
# SUCR:PROF.276:PROF.275
# GG23:PROF.276:PROF.514
# SUCR:PROF.278:PROF.277
# FG63:PROF.277:PROF.616

# %%
import mdtraj as md
import nglview as nv

viewpdb=md.load_pdb("ficoll.pdb")

view = nv.NGLWidget(nv.MDTrajTrajectory(viewpdb))
#view.clear_representations()
#view.add_licorice('',color="blue")
#view.add_licorice(':B',color="blue")
#view.add_licorice(f'{selectresidue}:B',color="green")
#view.add_spacefill(f'{selectresidue}:B and .CA', radius="0.5", color="red")
view.camera='orthographic'

view
